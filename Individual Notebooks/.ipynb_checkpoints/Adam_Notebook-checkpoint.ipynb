# %% [markdown]
# # Fix format
# Adam Burstyn
# Group

# %% [markdown]
# This notebook contains the code to explore the tables provided for the movie information

# %%
import pandas as pd
import sqlite3
import re
import matplotlib.pyplot as plt
from scipy import stats
# %matplotlib inline
from get_total_movie_info import *

# %% [markdown]
# ## Explore links to combine tables

# %% [markdown]
# ### Load tables from data scources

# %%
# load tables from the sql db

# connect  to db
conn = sqlite3.connect("../Data/im.db")

# load movie basics table
movie_basics_df = pd.read_sql("SELECT * FROM movie_basics;", conn)

# load movie ratings table
movie_ratings_df = pd.read_sql("SELECT * FROM movie_ratings;", conn)

# load movie aka table
movie_akas_df = pd.read_sql("SELECT * FROM movie_akas;", conn)

# %% [markdown]
# ### Load data from files

# %%
# load movie gross data
movie_gross = pd.read_csv("../Data/bom.movie_gross.csv")

# load movie budget/gross data
movie_budgets = pd.read_csv("../Data/tn.movie_budgets.csv")

# %% [markdown]
# ### Preview tables

# %%
movie_budgets
# Out:
#       id  release_date                                        movie  \
# 0      1  Dec 18, 2009                                       Avatar
# 1      2  May 20, 2011  Pirates of the Caribbean: On Stranger Tides
# 2      3   Jun 7, 2019                                 Dark Phoenix
# 3      4   May 1, 2015                      Avengers: Age of Ultron
# 4      5  Dec 15, 2017            Star Wars Ep. VIII: The Last Jedi
# ...   ..           ...                                          ...
# 5777  78  Dec 31, 2018                                       Red 11
# 5778  79   Apr 2, 1999                                    Following
# 5779  80  Jul 13, 2005                Return to the Land of Wonders
# 5780  81  Sep 29, 2015                         A Plague So Pleasant
# 5781  82   Aug 5, 2005                            My Date With Drew
#
#      production_budget domestic_gross worldwide_gross
# 0         $425,000,000   $760,507,625  $2,776,345,279
# 1         $410,600,000   $241,063,875  $1,045,663,875
# 2         $350,000,000    $42,762,350    $149,762,350
# 3         $330,600,000   $459,005,868  $1,403,013,963
# 4         $317,000,000   $620,181,382  $1,316,721,747
# ...                ...            ...             ...
# 5777            $7,000             $0              $0
# 5778            $6,000        $48,482        $240,495
# 5779            $5,000         $1,338          $1,338
# 5780            $1,400             $0              $0
# 5781            $1,100       $181,041        $181,041
#
# [5782 rows x 6 columns]

# %%
movie_gross
# Out:
#                                             title      studio  domestic_gross  \
# 0                                     Toy Story 3          BV     415000000.0
# 1                      Alice in Wonderland (2010)          BV     334200000.0
# 2     Harry Potter and the Deathly Hallows Part 1          WB     296000000.0
# 3                                       Inception          WB     292600000.0
# 4                             Shrek Forever After        P/DW     238700000.0
# ...                                           ...         ...             ...
# 3382                                    The Quake       Magn.          6200.0
# 3383                  Edward II (2018 re-release)          FM          4800.0
# 3384                                     El Pacto        Sony          2500.0
# 3385                                     The Swan  Synergetic          2400.0
# 3386                            An Actor Prepares       Grav.          1700.0
#
#      foreign_gross  year
# 0        652000000  2010
# 1        691300000  2010
# 2        664300000  2010
# 3        535700000  2010
# 4        513900000  2010
# ...            ...   ...
# 3382           NaN  2018
# 3383           NaN  2018
# 3384           NaN  2018
# 3385           NaN  2018
# 3386           NaN  2018
#
# [3387 rows x 5 columns]

# %%
movie_basics_df
# Out:
#          movie_id                                primary_title  \
# 0       tt0063540                                    Sunghursh
# 1       tt0066787              One Day Before the Rainy Season
# 2       tt0069049                   The Other Side of the Wind
# 3       tt0069204                              Sabse Bada Sukh
# 4       tt0100275                     The Wandering Soap Opera
# ...           ...                                          ...
# 146139  tt9916538                          Kuambil Lagi Hatiku
# 146140  tt9916622  Rodolpho Teóphilo - O Legado de um Pioneiro
# 146141  tt9916706                              Dankyavar Danka
# 146142  tt9916730                                       6 Gunn
# 146143  tt9916754               Chico Albuquerque - Revelações
#
#                                      original_title  start_year  \
# 0                                         Sunghursh        2013
# 1                                   Ashad Ka Ek Din        2019
# 2                        The Other Side of the Wind        2018
# 3                                   Sabse Bada Sukh        2018
# 4                             La Telenovela Errante        2017
# ...                                             ...         ...
# 146139                          Kuambil Lagi Hatiku        2019
# 146140  Rodolpho Teóphilo - O Legado de um Pioneiro        2015
# 146141                              Dankyavar Danka        2013
# 146142                                       6 Gunn        2017
# 146143               Chico Albuquerque - Revelações        2013
#
#         runtime_minutes                genres
# 0                 175.0    Action,Crime,Drama
# 1                 114.0       Biography,Drama
# 2                 122.0                 Drama
# 3                   NaN          Comedy,Drama
# 4                  80.0  Comedy,Drama,Fantasy
# ...                 ...                   ...
# 146139            123.0                 Drama
# 146140              NaN           Documentary
# 146141              NaN                Comedy
# 146142            116.0                  None
# 146143              NaN           Documentary
#
# [146144 rows x 6 columns]

# %%
movie_ratings_df
# Out:
#          movie_id  averagerating  numvotes
# 0      tt10356526            8.3        31
# 1      tt10384606            8.9       559
# 2       tt1042974            6.4        20
# 3       tt1043726            4.2     50352
# 4       tt1060240            6.5        21
# ...           ...            ...       ...
# 73851   tt9805820            8.1        25
# 73852   tt9844256            7.5        24
# 73853   tt9851050            4.7        14
# 73854   tt9886934            7.0         5
# 73855   tt9894098            6.3       128
#
# [73856 rows x 3 columns]

# %% [markdown]
# * only about half of the movies have ratings, is it worth exploring an algorithm to impute the missing ratings?

# %%
movie_akas_df
# Out:
#          movie_id  ordering                                    title region  \
# 0       tt0369610        10                            Джурасик свят     BG
# 1       tt0369610        11                        Jurashikku warudo     JP
# 2       tt0369610        12  Jurassic World: O Mundo dos Dinossauros     BR
# 3       tt0369610        13                  O Mundo dos Dinossauros     BR
# 4       tt0369610        14                           Jurassic World     FR
# ...           ...       ...                                      ...    ...
# 331698  tt9827784         2                       Sayonara kuchibiru   None
# 331699  tt9827784         3                            Farewell Song    XWW
# 331700  tt9880178         1                              La atención   None
# 331701  tt9880178         2                              La atención     ES
# 331702  tt9880178         3                            The Attention    XWW
#
#        language        types   attributes  is_original_title
# 0            bg         None         None                0.0
# 1          None  imdbDisplay         None                0.0
# 2          None  imdbDisplay         None                0.0
# 3          None         None  short title                0.0
# 4          None  imdbDisplay         None                0.0
# ...         ...          ...          ...                ...
# 331698     None     original         None                1.0
# 331699       en  imdbDisplay         None                0.0
# 331700     None     original         None                1.0
# 331701     None         None         None                0.0
# 331702       en  imdbDisplay         None                0.0
#
# [331703 rows x 8 columns]

# %% [markdown]
# ### Combine SQL tables

# %%
# join tables on movie_id
df = movie_ratings_df.merge(movie_basics_df, how="inner", on="movie_id")
df = df.merge(movie_akas_df, how="inner", on="movie_id")
df
# Out:
#          movie_id  averagerating  numvotes  \
# 0       tt1042974            6.4        20
# 1       tt1042974            6.4        20
# 2       tt1042974            6.4        20
# 3       tt1043726            4.2     50352
# 4       tt1043726            4.2     50352
# ...           ...            ...       ...
# 261801  tt9691896            6.3        21
# 261802  tt9844256            7.5        24
# 261803  tt9844256            7.5        24
# 261804  tt9844256            7.5        24
# 261805  tt9844256            7.5        24
#
#                                             primary_title  \
# 0                                               Just Inès
# 1                                               Just Inès
# 2                                               Just Inès
# 3                                  The Legend of Hercules
# 4                                  The Legend of Hercules
# ...                                                   ...
# 261801                                                Out
# 261802  Code Geass: Lelouch of the Rebellion - Glorifi...
# 261803  Code Geass: Lelouch of the Rebellion - Glorifi...
# 261804  Code Geass: Lelouch of the Rebellion - Glorifi...
# 261805  Code Geass: Lelouch of the Rebellion - Glorifi...
#
#                                           original_title  start_year  \
# 0                                              Just Inès        2010
# 1                                              Just Inès        2010
# 2                                              Just Inès        2010
# 3                                 The Legend of Hercules        2014
# 4                                 The Legend of Hercules        2014
# ...                                                  ...         ...
# 261801                                        Coming Out        2018
# 261802  Code Geass: Lelouch of the Rebellion Episode III        2018
# 261803  Code Geass: Lelouch of the Rebellion Episode III        2018
# 261804  Code Geass: Lelouch of the Rebellion Episode III        2018
# 261805  Code Geass: Lelouch of the Rebellion Episode III        2018
#
#         runtime_minutes                    genres  ordering  \
# 0                  90.0                     Drama         1
# 1                  90.0                     Drama         2
# 2                  90.0                     Drama         3
# 3                  99.0  Action,Adventure,Fantasy        10
# 4                  99.0  Action,Adventure,Fantasy        11
# ...                 ...                       ...       ...
# 261801             64.0               Documentary         4
# 261802            120.0   Action,Animation,Sci-Fi         1
# 261803            120.0   Action,Animation,Sci-Fi         2
# 261804            120.0   Action,Animation,Sci-Fi         3
# 261805            120.0   Action,Animation,Sci-Fi         4
#
#                                                     title region language  \
# 0                                               Just Inès   None     None
# 1                                               Samo Ines     RS     None
# 2                                               Just Inès     GB     None
# 3                                  The Legend of Hercules   None     None
# 4                               Hércules - A Lenda Começa     PT     None
# ...                                                   ...    ...      ...
# 261801                                         Coming Out   None     None
# 261802   Code Geass: Lelouch of the Rebellion Episode III     JP     None
# 261803   Code Geass: Lelouch of the Rebellion Episode III   None     None
# 261804  Code Geass: Lelouch of the Rebellion - Glorifi...    XWW       en
# 261805     Code Geass: Lelouch of the Rebellion - Emperor    XWW       en
#
#               types attributes  is_original_title
# 0          original       None                1.0
# 1       imdbDisplay       None                0.0
# 2              None       None                0.0
# 3          original       None                1.0
# 4       imdbDisplay       None                0.0
# ...             ...        ...                ...
# 261801     original       None                1.0
# 261802         None       None                0.0
# 261803     original       None                1.0
# 261804  imdbDisplay       None                0.0
# 261805  imdbDisplay       None                0.0
#
# [261806 rows x 15 columns]

# %% [markdown]
# ### Keep only US movies

# %%
# find the tag for US region
df["region"].unique()
# Out:
# array([None, 'RS', 'GB', 'PT', 'JP', 'AL', 'HR', 'VN', 'IT', 'GR', 'UA',
#        'RO', 'US', 'CA', 'CL', 'MX', 'RU', 'TR', 'IL', 'AR', 'PE', 'FR',
#        'ES', 'BR', 'PL', 'BG', 'HU', 'VE', 'SE', 'XWW', 'XEU', 'SI', 'UY',
#        'FI', 'DE', 'PH', 'NO', 'DK', 'EE', 'BE', 'LT', 'CO', 'CZ', 'AT',
#        'GE', 'IE', 'ZA', 'BA', 'LV', 'AU', 'LU', 'IN', 'KR', 'IR', 'NL',
#        'DZ', 'CN', 'NZ', 'ID', 'MY', 'JO', 'RW', 'EG', 'CH', 'LI', 'TH',
#        'BF', 'CSXX', 'SG', 'NP', 'SK', 'BD', 'PA', 'KE', 'PK', 'PS', 'HK',
#        'MK', 'KZ', 'TW', 'LK', 'IS', 'MW', 'DO', 'BO', 'PY', 'SL', 'AZ',
#        'AF', 'AE', 'PR', 'CU', 'NG', 'IQ', 'AM', 'CY', 'GU', 'HN', 'XAS',
#        'TN', 'BY', 'SA', 'HT', 'MT', 'BH', 'KH', 'KG', 'FO', 'SV', 'XSA',
#        'GT', 'LB', 'BT', 'CR', 'XKV', 'UZ', 'MA', 'ME', 'LA', 'SB', 'XKO',
#        'SY', 'TZ', 'QA', 'MN', 'EC', 'JM', 'NE', 'AN', 'MV', 'TT', 'ET',
#        'CF', 'CM', 'MM', 'TJ', 'SM', 'MD', 'GW', 'KW', 'AD', 'BB', 'MZ',
#        'BS', 'SO', 'BZ', 'IM', 'MC', 'AW', 'UG', 'BN', 'MH', 'AO', 'GH',
#        'ZM', 'GP', 'NI', 'CSHH', 'SUHH', 'CV', 'SN', 'TD', 'PG', 'MU',
#        'XYU', 'GL', 'CG', 'MQ', 'LY', 'BJ', 'GM', 'GA', 'CI', 'ML', 'MO',
#        'CD', 'VI', 'TL', 'MG', 'KP', 'SZ', 'YE', 'BM', 'FJ', 'SR', 'OM',
#        'XWG', 'AG', 'PF', 'XNA', 'ZW', 'MR', 'TO', 'NC', 'SD', 'VC', 'TM'],
#       dtype=object)

# %% [markdown]
# region is US

# %%
us_movies = df[df["region"]=="US"]
us_movies
# Out:
#          movie_id  averagerating  numvotes             primary_title  \
# 14      tt1043726            4.2     50352    The Legend of Hercules
# 26      tt1043726            4.2     50352    The Legend of Hercules
# 29      tt1043726            4.2     50352    The Legend of Hercules
# 42      tt1094666            7.0      1613                The Hammer
# 45      tt1094666            7.0      1613                The Hammer
# ...           ...            ...       ...                       ...
# 261737  tt9165332            7.4       710              Chitralahari
# 261760  tt9382596            4.1       293  The Car: Road to Revenge
# 261761  tt9382596            4.1       293  The Car: Road to Revenge
# 261762  tt9382596            4.1       293  The Car: Road to Revenge
# 261778  tt9558612            3.7      4057          PM Narendra Modi
#
#                   original_title  start_year  runtime_minutes  \
# 14        The Legend of Hercules        2014             99.0
# 26        The Legend of Hercules        2014             99.0
# 29        The Legend of Hercules        2014             99.0
# 42                        Hamill        2010            108.0
# 45                        Hamill        2010            108.0
# ...                          ...         ...              ...
# 261737              Chitralahari        2019            131.0
# 261760  The Car: Road to Revenge        2019             89.0
# 261761  The Car: Road to Revenge        2019             89.0
# 261762  The Car: Road to Revenge        2019             89.0
# 261778          PM Narendra Modi        2019            136.0
#
#                           genres  ordering                        title  \
# 14      Action,Adventure,Fantasy        20       The Legend of Hercules
# 26      Action,Adventure,Fantasy        31    Untitled Hercules Project
# 29      Action,Adventure,Fantasy         5  Hercules: The Legend Begins
# 42         Biography,Drama,Sport         4                       Hamill
# 45         Biography,Drama,Sport         7                   The Hammer
# ...                          ...       ...                          ...
# 261737                     Drama         2                 Chitralahari
# 261760    Action,Horror,Thriller         1   The Car 2: Road to Revenge
# 261761    Action,Horror,Thriller         2                    The Car 2
# 261762    Action,Horror,Thriller         3     The Car: Road to Revenge
# 261778           Biography,Drama         1             PM Narendra Modi
#
#        region language        types attributes  is_original_title
# 14         US     None         None       None                0.0
# 26         US     None      working       None                0.0
# 29         US     None      working       None                0.0
# 42         US     None     festival       None                0.0
# 45         US     None  imdbDisplay       None                0.0
# ...       ...      ...          ...        ...                ...
# 261737     US       en  imdbDisplay       None                0.0
# 261760     US     None      working       None                0.0
# 261761     US     None      working       None                0.0
# 261762     US     None         None       None                0.0
# 261778     US       en  imdbDisplay       None                0.0
#
# [30194 rows x 15 columns]

# %%
us_movies["movie_id"].nunique()
# Out:
# 26654

# %% [markdown]
# There are duplicate movie ids

# %%
# keep only 1 entry for each movie id
us_movies = us_movies.drop_duplicates(subset=["movie_id"])
us_movies
# Out:
#          movie_id  averagerating  numvotes             primary_title  \
# 14      tt1043726            4.2     50352    The Legend of Hercules
# 42      tt1094666            7.0      1613                The Hammer
# 64      tt1161457            4.2       148                Vanquisher
# 76      tt1171222            5.1      8296             Baggage Claim
# 85      tt1174693            5.8      2381       The Four-Faced Liar
# ...           ...            ...       ...                       ...
# 261715  tt8948790            9.0      1778                    Jersey
# 261734  tt9127488            9.3        10                    Postal
# 261737  tt9165332            7.4       710              Chitralahari
# 261760  tt9382596            4.1       293  The Car: Road to Revenge
# 261778  tt9558612            3.7      4057          PM Narendra Modi
#
#                   original_title  start_year  runtime_minutes  \
# 14        The Legend of Hercules        2014             99.0
# 42                        Hamill        2010            108.0
# 64                The Vanquisher        2016             90.0
# 76                 Baggage Claim        2013             96.0
# 85           The Four-Faced Liar        2010             87.0
# ...                          ...         ...              ...
# 261715                    Jersey        2019            157.0
# 261734                    Postal        2019             77.0
# 261737              Chitralahari        2019            131.0
# 261760  The Car: Road to Revenge        2019             89.0
# 261778          PM Narendra Modi        2019            136.0
#
#                           genres  ordering                       title region  \
# 14      Action,Adventure,Fantasy        20      The Legend of Hercules     US
# 42         Biography,Drama,Sport         4                      Hamill     US
# 64       Action,Adventure,Sci-Fi         1                  Vanquisher     US
# 76                        Comedy         5               Baggage Claim     US
# 85          Comedy,Drama,Romance         5         The Four-Faced Liar     US
# ...                          ...       ...                         ...    ...
# 261715               Drama,Sport         3                      Jersey     US
# 261734                    Comedy         2                      Postal     US
# 261737                     Drama         2                Chitralahari     US
# 261760    Action,Horror,Thriller         1  The Car 2: Road to Revenge     US
# 261778           Biography,Drama         1            PM Narendra Modi     US
#
#        language        types attributes  is_original_title
# 14         None         None       None                0.0
# 42         None     festival       None                0.0
# 64         None         None  new title                0.0
# 76         None         None       None                0.0
# 85         None         None       None                0.0
# ...         ...          ...        ...                ...
# 261715       en  imdbDisplay       None                0.0
# 261734     None         None       None                0.0
# 261737       en  imdbDisplay       None                0.0
# 261760     None      working       None                0.0
# 261778       en  imdbDisplay       None                0.0
#
# [26654 rows x 15 columns]

# %% [markdown]
# ### Add in gross numbers

# %% [markdown]
# #### Clean movie title and year info for merging
# - use primary title as title
# - all lowercase
# - keep only alpha-numeric values
# - remove spaces
#     - to eliminate issues with titles contaning "Star Wars:Episode 3" vs "Star Wars: Episode 3"
#
# ** We will merge on title and year to differentiate between movies with the same title relseased in different year (remakes)

# %%
# use RegEx to keep only alpha-numeric values, remove spaces and make all letters lowercase 
#us_movies["title"] = us_movies["title"].map(lambda x: re.sub(r'[^A-Za-z0-9 ]+', '', x).lower())
us_movies["title"] = us_movies["primary_title"]

us_movies["title"] = us_movies["title"].map(lambda x: re.sub(r'[^A-Za-z0-9]+', '', x).lower())
movie_budgets["movie"] = movie_budgets["movie"].map(lambda x: re.sub(r'[^A-Za-z0-9]+', '', x).lower())
movie_gross["title"] = movie_gross["title"].map(lambda x: re.sub(r'[^A-Za-z0-9]+', '', x).lower())
# Out:
# <ipython-input-14-25be13c0b9d5>:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   us_movies["title"] = us_movies["primary_title"]
# <ipython-input-14-25be13c0b9d5>:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   us_movies["title"] = us_movies["title"].map(lambda x: re.sub(r'[^A-Za-z0-9]+', '', x).lower())

# %%
# get a year column as int to match other df data types
movie_budgets["year"] = movie_budgets["release_date"].map(lambda x: int(x[-4:]))
movie_budgets.head()
# Out:
#    id  release_date                                 movie production_budget  \
# 0   1  Dec 18, 2009                                avatar      $425,000,000
# 1   2  May 20, 2011  piratesofthecaribbeanonstrangertides      $410,600,000
# 2   3   Jun 7, 2019                           darkphoenix      $350,000,000
# 3   4   May 1, 2015                   avengersageofultron      $330,600,000
# 4   5  Dec 15, 2017             starwarsepviiithelastjedi      $317,000,000
#
#   domestic_gross worldwide_gross  year
# 0   $760,507,625  $2,776,345,279  2009
# 1   $241,063,875  $1,045,663,875  2011
# 2    $42,762,350    $149,762,350  2019
# 3   $459,005,868  $1,403,013,963  2015
# 4   $620,181,382  $1,316,721,747  2017

# %%
# rename columns to match for merging
movie_budgets.rename(columns={"movie": "title", "domestic_gross": "domestic_gross_movie_budgets",
                              "worldwide_gross": "worldwide_gross_movie_budgets"}, inplace=True)

movie_gross.rename(columns={"domestic_gross": "domestic_gross_movie_gross", 
                            "foreign_gross": "foreign_gross_movie_gross"}, inplace=True)

us_movies.rename(columns={"start_year": "year"}, inplace=True)
# Out:
# <ipython-input-16-8e52a97c0efb>:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   us_movies.rename(columns={"start_year": "year"}, inplace=True)

# %% [markdown]
# #### Merge dataframes to get all gross revenue info

# %%
final_gross_df1 = us_movies.merge(movie_budgets, on=["title", "year"], how="inner")#.drop_duplicates(subset=["movie_id"])
len(final_gross_df1), final_gross_df1["movie_id"].nunique()
# Out:
# (1412, 1412)

# %%
final_gross_df1.head()
# Out:
#     movie_id  averagerating  numvotes                         primary_title  \
# 0  tt1043726            4.2     50352                The Legend of Hercules
# 1  tt1171222            5.1      8296                         Baggage Claim
# 2  tt1210166            7.6    326657                             Moneyball
# 3  tt1212419            6.5     87288                             Hereafter
# 4  tt1229238            7.4    428142  Mission: Impossible - Ghost Protocol
#
#                          original_title  year  runtime_minutes  \
# 0                The Legend of Hercules  2014             99.0
# 1                         Baggage Claim  2013             96.0
# 2                             Moneyball  2011            133.0
# 3                             Hereafter  2010            129.0
# 4  Mission: Impossible - Ghost Protocol  2011            132.0
#
#                       genres  ordering                           title region  \
# 0   Action,Adventure,Fantasy        20             thelegendofhercules     US
# 1                     Comedy         5                    baggageclaim     US
# 2      Biography,Drama,Sport        14                       moneyball     US
# 3      Drama,Fantasy,Romance         4                       hereafter     US
# 4  Action,Adventure,Thriller        11  missionimpossibleghostprotocol     US
#
#   language        types attributes  is_original_title  id  release_date  \
# 0     None         None       None                0.0  42  Jan 10, 2014
# 1     None         None       None                0.0  38  Sep 27, 2013
# 2     None  imdbDisplay       None                0.0  15  Sep 23, 2011
# 3     None         None       None                0.0  61  Oct 15, 2010
# 4     None      working       None                0.0  98  Dec 16, 2011
#
#   production_budget domestic_gross_movie_budgets worldwide_gross_movie_budgets
# 0       $70,000,000                  $18,848,538                   $58,953,319
# 1        $8,500,000                  $21,569,509                   $22,885,836
# 2       $50,000,000                  $75,605,492                  $111,300,835
# 3       $50,000,000                  $32,746,941                  $108,660,270
# 4      $145,000,000                 $209,397,903                  $694,713,230

# %%
final_gross_df2 = us_movies.merge(movie_gross, on=["title", "year"], how="inner")#.drop_duplicates(subset=["movie_id"])
len(final_gross_df2), final_gross_df2["movie_id"].nunique()
# Out:
# (1437, 1437)

# %%
final_gross_df2.head()
# Out:
#     movie_id  averagerating  numvotes                         primary_title  \
# 0  tt1043726            4.2     50352                The Legend of Hercules
# 1  tt1171222            5.1      8296                         Baggage Claim
# 2  tt1210166            7.6    326657                             Moneyball
# 3  tt1212419            6.5     87288                             Hereafter
# 4  tt1229238            7.4    428142  Mission: Impossible - Ghost Protocol
#
#                          original_title  year  runtime_minutes  \
# 0                The Legend of Hercules  2014             99.0
# 1                         Baggage Claim  2013             96.0
# 2                             Moneyball  2011            133.0
# 3                             Hereafter  2010            129.0
# 4  Mission: Impossible - Ghost Protocol  2011            132.0
#
#                       genres  ordering                           title region  \
# 0   Action,Adventure,Fantasy        20             thelegendofhercules     US
# 1                     Comedy         5                    baggageclaim     US
# 2      Biography,Drama,Sport        14                       moneyball     US
# 3      Drama,Fantasy,Romance         4                       hereafter     US
# 4  Action,Adventure,Thriller        11  missionimpossibleghostprotocol     US
#
#   language        types attributes  is_original_title studio  \
# 0     None         None       None                0.0   LG/S
# 1     None         None       None                0.0   FoxS
# 2     None  imdbDisplay       None                0.0   Sony
# 3     None         None       None                0.0     WB
# 4     None      working       None                0.0   Par.
#
#    domestic_gross_movie_gross foreign_gross_movie_gross
# 0                  18800000.0                  42400000
# 1                  21600000.0                    887000
# 2                  75600000.0                  34600000
# 3                  32700000.0                  72500000
# 4                 209400000.0                 485300000

# %%
final_gross_all = pd.concat([final_gross_df1, final_gross_df2]).drop_duplicates(subset=["movie_id"])
len(final_gross_all), final_gross_all["movie_id"].nunique()
# Out:
# (1818, 1818)

# %%
final_gross_all.head()
# Out:
#     movie_id  averagerating  numvotes                         primary_title  \
# 0  tt1043726            4.2     50352                The Legend of Hercules
# 1  tt1171222            5.1      8296                         Baggage Claim
# 2  tt1210166            7.6    326657                             Moneyball
# 3  tt1212419            6.5     87288                             Hereafter
# 4  tt1229238            7.4    428142  Mission: Impossible - Ghost Protocol
#
#                          original_title  year  runtime_minutes  \
# 0                The Legend of Hercules  2014             99.0
# 1                         Baggage Claim  2013             96.0
# 2                             Moneyball  2011            133.0
# 3                             Hereafter  2010            129.0
# 4  Mission: Impossible - Ghost Protocol  2011            132.0
#
#                       genres  ordering                           title  ...  \
# 0   Action,Adventure,Fantasy        20             thelegendofhercules  ...
# 1                     Comedy         5                    baggageclaim  ...
# 2      Biography,Drama,Sport        14                       moneyball  ...
# 3      Drama,Fantasy,Romance         4                       hereafter  ...
# 4  Action,Adventure,Thriller        11  missionimpossibleghostprotocol  ...
#
#   attributes is_original_title    id  release_date  production_budget  \
# 0       None               0.0  42.0  Jan 10, 2014        $70,000,000
# 1       None               0.0  38.0  Sep 27, 2013         $8,500,000
# 2       None               0.0  15.0  Sep 23, 2011        $50,000,000
# 3       None               0.0  61.0  Oct 15, 2010        $50,000,000
# 4       None               0.0  98.0  Dec 16, 2011       $145,000,000
#
#    domestic_gross_movie_budgets worldwide_gross_movie_budgets studio  \
# 0                   $18,848,538                   $58,953,319    NaN
# 1                   $21,569,509                   $22,885,836    NaN
# 2                   $75,605,492                  $111,300,835    NaN
# 3                   $32,746,941                  $108,660,270    NaN
# 4                  $209,397,903                  $694,713,230    NaN
#
#   domestic_gross_movie_gross foreign_gross_movie_gross
# 0                        NaN                       NaN
# 1                        NaN                       NaN
# 2                        NaN                       NaN
# 3                        NaN                       NaN
# 4                        NaN                       NaN
#
# [5 rows x 23 columns]

# %% [markdown]
# ## View Data Visualizations

# %%
lkjlkjkj
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-23-893d49dd7b2d> in <module>
# ----> 1 lkjlkjkj
#
# NameError: name 'lkjlkjkj' is not defined

# %%
# get cleaned df the from groupwork
total_movie_info = get_total_movie_info()
total_movie_info.head()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 255873 entries, 0 to 255872
# Data columns (total 2 columns):
#  #   Column     Non-Null Count   Dtype
# ---  ------     --------------   -----
#  0   movie_id   255873 non-null  object
#  1   person_id  255873 non-null  object
# dtypes: object(2)
# memory usage: 3.9+ MB
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 73856 entries, 0 to 73855
# Data columns (total 3 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   movie_id       73856 non-null  object
#  1   averagerating  73856 non-null  float64
#  2   numvotes       73856 non-null  int64
# dtypes: float64(1), int64(1), object(1)
# memory usage: 1.7+ MB
#     movie_id  averagerating  numvotes           primary_title  \
# 0  tt1043726            4.2     50352  The Legend of Hercules
# 1  tt1171222            5.1      8296           Baggage Claim
# 2  tt1210166            7.6    326657               Moneyball
# 3  tt1212419            6.5     87288               Hereafter
# 4  tt6096334            6.4         5              Here After
#
#            original_title  start_year  runtime_minutes  \
# 0  The Legend of Hercules        2014             99.0
# 1           Baggage Claim        2013             96.0
# 2               Moneyball        2011            133.0
# 3               Hereafter        2010            129.0
# 4              Here After        2018             71.0
#
#                      genres  ordering                title  ...    id  \
# 0  Action,Adventure,Fantasy        20  thelegendofhercules  ...  42.0
# 1                    Comedy         5         baggageclaim  ...  38.0
# 2     Biography,Drama,Sport        14            moneyball  ...  15.0
# 3     Drama,Fantasy,Romance         4            hereafter  ...  61.0
# 4               Documentary         1            hereafter  ...  61.0
#
#    release_date production_budget domestic_gross_movie_budgets  \
# 0  Jan 10, 2014       $70,000,000                  $18,848,538
# 1  Sep 27, 2013        $8,500,000                  $21,569,509
# 2  Sep 23, 2011       $50,000,000                  $75,605,492
# 3  Oct 15, 2010       $50,000,000                  $32,746,941
# 4  Oct 15, 2010       $50,000,000                  $32,746,941
#
#    worldwide_gross_movie_budgets  year studio domestic_gross_movie_gross  \
# 0                    $58,953,319  2014    NaN                        NaN
# 1                    $22,885,836  2013    NaN                        NaN
# 2                   $111,300,835  2011    NaN                        NaN
# 3                   $108,660,270  2010    NaN                        NaN
# 4                   $108,660,270  2010    NaN                        NaN
#
#   foreign_gross_movie_gross   primary_name
# 0                       NaN    rennyharlin
# 1                       NaN  davidetalbert
# 2                       NaN  bennettmiller
# 3                       NaN  clinteastwood
# 4                       NaN       esycasey
#
# [5 rows x 25 columns]

# %%
counts = total_movie_info.groupby("genres").count()[["movie_id"]]
means = total_movie_info.groupby("genres").mean()[["clean_domestic_gross", "clean_worldwide_gross", "production_budget"]].head(50).sort_values("clean_domestic_gross", ascending=False)
means.merge(counts, how="inner", on="genres").rename(columns={"movie_id": "num_movies"})
# Out:
#                               clean_domestic_gross  clean_worldwide_gross  \
# genres
# Action,Adventure,Sci-Fi               2.043850e+08           5.710100e+08
# Action,Adventure,Animation            1.547655e+08           3.800515e+08
# Action,Comedy,Documentary             1.172297e+08           1.716858e+08
# Action,Adventure,Fantasy              1.158054e+08           2.261323e+08
# Action,Adventure,Family               1.036964e+08           3.028748e+08
# Action,Adventure,Comedy               1.020204e+08           3.511047e+08
# Action,Adventure,Thriller             9.764521e+07           3.408274e+08
# Action,Adventure,Western              9.136738e+07           2.112636e+08
# Action,Biography,Drama                8.826339e+07           1.752198e+08
# Action,Drama,Family                   8.546331e+07           2.638803e+08
# Action,Comedy,Thriller                7.546858e+07           1.727787e+08
# Action,Animation,Comedy               7.489580e+07           1.778869e+08
# Action,Comedy,Crime                   7.305510e+07           1.350894e+08
# Action,Adventure,Biography            7.089648e+07           2.254565e+08
# Action,Adventure,Horror               6.207580e+07           1.571116e+08
# Action,Documentary,Drama              6.000830e+07           6.245293e+07
# Action,Adventure,Drama                5.543133e+07           1.544755e+08
# Action,Adventure,Mystery              5.245647e+07           1.219678e+08
# Action,Biography,Comedy               5.134200e+07           1.355692e+08
# Action,Drama,Sci-Fi                   4.902681e+07           1.483277e+08
# Action,Comedy,Sport                   4.529032e+07           7.323926e+07
# Action,Adventure,Crime                4.503203e+07           1.297661e+08
# Action,Crime,Thriller                 4.114600e+07           1.203623e+08
# Action,Crime,Sci-Fi                   3.601086e+07           1.422247e+08
# Action,Drama,Mystery                  3.546811e+07           1.189135e+08
# Action,Comedy,Romance                 3.259558e+07           1.004711e+08
# Action,Comedy,Sci-Fi                  3.010271e+07           1.072818e+08
# Action,Comedy,Family                  2.430711e+07           4.675286e+07
# Action                                2.285843e+07           3.604967e+07
# Action,Crime,Drama                    2.137021e+07           4.485984e+07
# Action,Comedy,Drama                   1.793646e+07           3.396971e+07
# Action,Drama,History                  1.742425e+07           4.197548e+07
# Action,Comedy,Horror                  1.633438e+07           3.157372e+07
# Action,Comedy,Fantasy                 1.580566e+07           2.403986e+07
# Action,Comedy                         1.521505e+07           2.278783e+07
# Action,Drama,Fantasy                  7.384229e+06           7.622018e+06
# Action,Animation,Crime                3.800000e+06                    NaN
# Action,Documentary                    5.017520e+05           5.953886e+06
# Action,Adventure,Documentary          4.426380e+05           4.426380e+05
# Action,Biography,Crime                2.803450e+05           3.721988e+06
# Action,Drama,Sport                    2.060000e+05           1.490000e+07
# Action,Drama,Romance                  1.680000e+05                    NaN
# Action,Crime                          1.370000e+05           2.780000e+07
# Action,Animation,Sci-Fi               1.010000e+05                    NaN
# Action,Drama                          5.405850e+04           4.836700e+04
# Action,Documentary,History            4.060000e+04                    NaN
# Action,Drama,Horror                   2.100000e+04                    NaN
# Action,Adventure                      3.293500e+03           6.605058e+06
# Action,Biography,Documentary          1.822000e+03           1.822000e+03
# Action,Crime,Fantasy                  0.000000e+00           0.000000e+00
#
#                               production_budget  num_movies
# genres
# Action,Adventure,Sci-Fi            1.615222e+08          37
# Action,Adventure,Animation         1.194688e+08          20
# Action,Comedy,Documentary          2.000000e+07           1
# Action,Adventure,Fantasy           1.089789e+08          21
# Action,Adventure,Family            1.422500e+08           4
# Action,Adventure,Comedy            9.455882e+07          24
# Action,Adventure,Thriller          1.065000e+08           8
# Action,Adventure,Western           1.825000e+08           2
# Action,Biography,Drama             4.650000e+07           6
# Action,Drama,Family                1.100000e+08           1
# Action,Comedy,Thriller             3.000000e+07           1
# Action,Animation,Comedy            4.700000e+07           7
# Action,Comedy,Crime                4.645833e+07          29
# Action,Adventure,Biography         8.375000e+07           4
# Action,Adventure,Horror            1.124000e+08           4
# Action,Documentary,Drama           1.300000e+07           1
# Action,Adventure,Drama             7.903000e+07          27
# Action,Adventure,Mystery           5.264500e+07           4
# Action,Biography,Comedy            5.000000e+07           1
# Action,Drama,Sci-Fi                5.602778e+07           9
# Action,Comedy,Sport                4.200000e+07           1
# Action,Adventure,Crime             4.690000e+07          11
# Action,Crime,Thriller              3.995000e+07          30
# Action,Crime,Sci-Fi                8.250000e+07           2
# Action,Drama,Mystery               7.140000e+07           5
# Action,Comedy,Romance              4.000000e+07           4
# Action,Comedy,Sci-Fi               4.600000e+07           4
# Action,Comedy,Family               2.800000e+07           1
# Action                             2.561500e+07          12
# Action,Crime,Drama                 2.427121e+07          43
# Action,Comedy,Drama                1.475000e+07           5
# Action,Drama,History               5.535000e+07           9
# Action,Comedy,Horror               2.800000e+07           6
# Action,Comedy,Fantasy              4.500000e+07           2
# Action,Comedy                      1.650000e+07           6
# Action,Drama,Fantasy               3.275000e+07           2
# Action,Animation,Crime                      NaN           1
# Action,Documentary                 1.500000e+07           1
# Action,Adventure,Documentary       8.500000e+05           1
# Action,Biography,Crime             3.000000e+07           2
# Action,Drama,Sport                          NaN           1
# Action,Drama,Romance                        NaN           1
# Action,Crime                                NaN           1
# Action,Animation,Sci-Fi                     NaN           2
# Action,Drama                       1.050000e+07           4
# Action,Documentary,History                  NaN           1
# Action,Drama,Horror                         NaN           1
# Action,Adventure                   1.083333e+07           4
# Action,Biography,Documentary       5.000000e+05           1
# Action,Crime,Fantasy               9.000000e+07           1

# %%
# clean gross columns for graphing
total_movie_info["clean_domestic_gross"] = handle_NaN(total_movie_info["domestic_gross_movie_budgets"], total_movie_info["domestic_gross_movie_gross"])
total_movie_info["clean_worldwide_gross"] = handle_NaN(total_movie_info["worldwide_gross_movie_budgets"], total_movie_info["foreign_gross_movie_gross"])
total_movie_info["clean_domestic_gross"] = dollar_to_float(total_movie_info["clean_domestic_gross"])
total_movie_info["clean_worldwide_gross"] = dollar_to_float(total_movie_info["clean_worldwide_gross"])
total_movie_info["production_budget"] = dollar_to_float(total_movie_info["production_budget"])
total_movie_info[["clean_domestic_gross", "clean_worldwide_gross"]]
# Out:
#       clean_domestic_gross  clean_worldwide_gross
# 0               18848538.0             58953319.0
# 1               21569509.0             22885836.0
# 2               75605492.0            111300835.0
# 3               32746941.0            108660270.0
# 4               32746941.0            108660270.0
# ...                    ...                    ...
# 2577             5800000.0             13300000.0
# 2578               81100.0                    NaN
# 2579               59200.0                    NaN
# 2580             6800000.0              5000000.0
# 2581              100000.0               132000.0
#
# [2579 rows x 2 columns]

# %%
# is there a relationship between domestic gross and foreign gross
ax = total_movie_info.plot(x="clean_domestic_gross", y="clean_worldwide_gross", kind="scatter")

# plot regression line
m = stats.linregress(total_movie_info["clean_domestic_gross"].to_list(), y=total_movie_info["clean_worldwide_gross"].to_list())
t = [m.slope * i + m.intercept for i in total_movie_info["clean_domestic_gross"]]

total_movie_info["regression"] = t

total_movie_info.plot.line(x="clean_domestic_gross", y="regression", color='r', ax=ax);

# %%
m = stats.linregress(total_movie_info["clean_domestic_gross"].to_list(), y=total_movie_info["clean_worldwide_gross"].to_list())
m
# Out:
# LinregressResult(slope=nan, intercept=nan, rvalue=nan, pvalue=nan, stderr=nan, intercept_stderr=nan)

# %%
total_movie_info["clean_worldwide_gross"].isna().sum()
# Out:
# 461

# %% [markdown]
# ## Investigate merging Rotten Tomatoes Data

# %% [markdown]
# ### Load data

# %%
# load RT data
rt_movie_info = pd.read_table("../Data/rt.movie_info.tsv")
rt_reviews = pd.read_table("../Data/rt.reviews.tsv", encoding = 'latin-1')

# %%
rt_movie_info.head()

# %%
rt_reviews.head()

# %% [markdown]
# *There are multiple ratings for each movie, they will need to be averaged out if used

# %% [markdown]
# We will attempt to merge RT data with the other tables based on director and release date (highly unlikely that a producer released multiple movies on the same date)
