# %%
#import all the libraries 
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from scipy import stats
import sqlite3
# %matplotlib inline
plt.rcParams['figure.figsize'] = (10, 10)
plt.style.available
from get_total_movie_info import *

# %%
df = get_total_movie_info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 255873 entries, 0 to 255872
# Data columns (total 2 columns):
#  #   Column     Non-Null Count   Dtype
# ---  ------     --------------   -----
#  0   movie_id   255873 non-null  object
#  1   person_id  255873 non-null  object
# dtypes: object(2)
# memory usage: 3.9+ MB
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 73856 entries, 0 to 73855
# Data columns (total 3 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   movie_id       73856 non-null  object
#  1   averagerating  73856 non-null  float64
#  2   numvotes       73856 non-null  int64
# dtypes: float64(1), int64(1), object(1)
# memory usage: 1.7+ MB

# %%
df
# Out:
#        movie_id  averagerating  numvotes           primary_title  \
# 0     tt1043726            4.2     50352  The Legend of Hercules
# 1     tt1171222            5.1      8296           Baggage Claim
# 2     tt1210166            7.6    326657               Moneyball
# 3     tt1212419            6.5     87288               Hereafter
# 4     tt6096334            6.4         5              Here After
# ...         ...            ...       ...                     ...
# 2577  tt2132285            5.6     77726          The Bling Ring
# 2578  tt2205697            7.2     78903          Stuck in Love.
# 2579  tt2463288            6.0     48134           Walk of Shame
# 2580  tt7008872            7.0     18768              Boy Erased
# 2581  tt7315484            5.2     22399             The Silence
#
#               original_title  start_year  runtime_minutes  \
# 0     The Legend of Hercules        2014             99.0
# 1              Baggage Claim        2013             96.0
# 2                  Moneyball        2011            133.0
# 3                  Hereafter        2010            129.0
# 4                 Here After        2018             71.0
# ...                      ...         ...              ...
# 2577          The Bling Ring        2013             90.0
# 2578          Stuck in Love.        2012             97.0
# 2579           Walk of Shame        2014             95.0
# 2580              Boy Erased        2018            115.0
# 2581             The Silence        2019             90.0
#
#                         genres  ordering                title  ...    id  \
# 0     Action,Adventure,Fantasy        20  thelegendofhercules  ...  42.0
# 1                       Comedy         5         baggageclaim  ...  38.0
# 2        Biography,Drama,Sport        14            moneyball  ...  15.0
# 3        Drama,Fantasy,Romance         4            hereafter  ...  61.0
# 4                  Documentary         1            hereafter  ...  61.0
# ...                        ...       ...                  ...  ...   ...
# 2577     Biography,Crime,Drama         1         theblingring  ...   NaN
# 2578      Comedy,Drama,Romance         6          stuckinlove  ...   NaN
# 2579                    Comedy        12          walkofshame  ...   NaN
# 2580           Biography,Drama        16            boyerased  ...   NaN
# 2581           Horror,Thriller         5           thesilence  ...   NaN
#
#       release_date production_budget domestic_gross_movie_budgets  \
# 0     Jan 10, 2014       $70,000,000                  $18,848,538
# 1     Sep 27, 2013        $8,500,000                  $21,569,509
# 2     Sep 23, 2011       $50,000,000                  $75,605,492
# 3     Oct 15, 2010       $50,000,000                  $32,746,941
# 4     Oct 15, 2010       $50,000,000                  $32,746,941
# ...            ...               ...                          ...
# 2577           NaN               NaN                          NaN
# 2578           NaN               NaN                          NaN
# 2579           NaN               NaN                          NaN
# 2580           NaN               NaN                          NaN
# 2581           NaN               NaN                          NaN
#
#       worldwide_gross_movie_budgets  year studio domestic_gross_movie_gross  \
# 0                       $58,953,319  2014    NaN                        NaN
# 1                       $22,885,836  2013    NaN                        NaN
# 2                      $111,300,835  2011    NaN                        NaN
# 3                      $108,660,270  2010    NaN                        NaN
# 4                      $108,660,270  2010    NaN                        NaN
# ...                             ...   ...    ...                        ...
# 2577                            NaN  2013    A24                  5800000.0
# 2578                            NaN  2013    MNE                    81100.0
# 2579                            NaN  2014    FCW                    59200.0
# 2580                            NaN  2018  Focus                  6800000.0
# 2581                            NaN  2013   MBox                   100000.0
#
#      foreign_gross_movie_gross   primary_name
# 0                          NaN    rennyharlin
# 1                          NaN  davidetalbert
# 2                          NaN  bennettmiller
# 3                          NaN  clinteastwood
# 4                          NaN       esycasey
# ...                        ...            ...
# 2577                  13300000   sofiacoppola
# 2578                       NaN      joshboone
# 2579                       NaN    stevenbrill
# 2580                   5000000   joeledgerton
# 2581                    132000  johnrleonetti
#
# [2579 rows x 25 columns]

# %% [markdown]
# ### Gross Box Office

# %%
movie_gross = pd.read_csv("../Data/bom.movie_gross.csv")
movie_gross.head()
#Domestic Gross and Foreign Gross are hard to read, because numbers are very large, we should adjust the values
#probably by making new columns as domestic_gross_mil and foreign_gross_mil
# Out:
#                                          title studio  domestic_gross  \
# 0                                  Toy Story 3     BV     415000000.0
# 1                   Alice in Wonderland (2010)     BV     334200000.0
# 2  Harry Potter and the Deathly Hallows Part 1     WB     296000000.0
# 3                                    Inception     WB     292600000.0
# 4                          Shrek Forever After   P/DW     238700000.0
#
#   foreign_gross  year
# 0     652000000  2010
# 1     691300000  2010
# 2     664300000  2010
# 3     535700000  2010
# 4     513900000  2010

# %%
clean_df = movie_gross['title'].map(lambda x: x.lower())
clean_df.head()
# Out:
# 0                                    toy story 3
# 1                     alice in wonderland (2010)
# 2    harry potter and the deathly hallows part 1
# 3                                      inception
# 4                            shrek forever after
# Name: title, dtype: object

# %%
clean_df = movie_gross['title'].apply(lambda x: x.strip())
clean_df.head()
# Out:
# 0                                    Toy Story 3
# 1                     Alice in Wonderland (2010)
# 2    Harry Potter and the Deathly Hallows Part 1
# 3                                      Inception
# 4                            Shrek Forever After
# Name: title, dtype: object

# %% [markdown]
# ### The Movies DB

# %%
df = pd.read_csv('../Data/tmdb.movies.csv', index_col=0)
df.head()
# Out:
#              genre_ids     id original_language  \
# 0      [12, 14, 10751]  12444                en
# 1  [14, 12, 16, 10751]  10191                en
# 2        [12, 28, 878]  10138                en
# 3      [16, 35, 10751]    862                en
# 4        [28, 878, 12]  27205                en
#
#                                  original_title  popularity release_date  \
# 0  Harry Potter and the Deathly Hallows: Part 1      33.533   2010-11-19
# 1                      How to Train Your Dragon      28.734   2010-03-26
# 2                                    Iron Man 2      28.515   2010-05-07
# 3                                     Toy Story      28.005   1995-11-22
# 4                                     Inception      27.920   2010-07-16
#
#                                           title  vote_average  vote_count
# 0  Harry Potter and the Deathly Hallows: Part 1           7.7       10788
# 1                      How to Train Your Dragon           7.7        7610
# 2                                    Iron Man 2           6.8       12368
# 3                                     Toy Story           7.9       10174
# 4                                     Inception           8.3       22186

# %% [markdown]
# ### Comparing orignial_title and title

# %%
df.shape
# Out:
# (26517, 9)

# %%
df[['original_title', 'title']].head(10)
# Out:
#                                       original_title  \
# 0       Harry Potter and the Deathly Hallows: Part 1
# 1                           How to Train Your Dragon
# 2                                         Iron Man 2
# 3                                          Toy Story
# 4                                          Inception
# 5  Percy Jackson & the Olympians: The Lightning T...
# 6                                             Avatar
# 7                                        Toy Story 3
# 8                                      Despicable Me
# 9                                           Megamind
#
#                                                title
# 0       Harry Potter and the Deathly Hallows: Part 1
# 1                           How to Train Your Dragon
# 2                                         Iron Man 2
# 3                                          Toy Story
# 4                                          Inception
# 5  Percy Jackson & the Olympians: The Lightning T...
# 6                                             Avatar
# 7                                        Toy Story 3
# 8                                      Despicable Me
# 9                                           Megamind

# %%
df['original_title'].value_counts()
# Out:
# Eden                                7
# Home                                6
# Aftermath                           5
# Truth or Dare                       5
# Lucky                               5
#                                    ..
# गोलमाल 3                            1
# Return of the Killer Shrews         1
# The Confirmation                    1
# Hoops & Yoyo's Haunted Halloween    1
# B&B                                 1
# Name: original_title, Length: 24835, dtype: int64

# %%
df['title'].value_counts()
# Out:
# Home                           7
# Eden                           7
# Aftermath                      5
# The Box                        5
# Lucky                          5
#                               ..
# Anarchy Parlor                 1
# Mr. Write                      1
# Le Week-End                    1
# Return of the Killer Shrews    1
# Black Bread                    1
# Name: title, Length: 24688, dtype: int64

# %%
df.duplicated().value_counts()
# Out:
# False    25497
# True      1020
# dtype: int64

# %%
df[df.duplicated(keep=False)].sort_values(by='original_title')
# Out:
#                  genre_ids      id original_language  \
# 9191                  [99]   95383                en
# 6315                  [99]   95383                en
# 20070      [99, 36, 10770]  430364                en
# 26340      [99, 36, 10770]  430364                en
# 18016          [18, 10749]  416691                en
# ...                    ...     ...               ...
# 21659          [18, 10749]   88752                zh
# 13823             [35, 18]  281139                zh
# 17054             [35, 18]  281139                zh
# 17659  [36, 18, 10752, 28]  407887                ko
# 20952  [36, 18, 10752, 28]  407887                ko
#
#                                        original_title  popularity  \
# 9191                                       $ellebrity       1.420
# 6315                                       $ellebrity       1.420
# 20070  '85: The Greatest Team in Pro Football History       0.600
# 26340  '85: The Greatest Team in Pro Football History       0.600
# 18016                                         1 Night       5.409
# ...                                               ...         ...
# 21659                                          當愛來的時候       2.621
# 13823                                        行動代號：孫中山       0.600
# 17054                                        行動代號：孫中山       0.600
# 17659                                          인천상륙작전       8.810
# 20952                                          인천상륙작전       8.810
#
#       release_date                                           title  \
# 9191    2013-01-11                                      $ellebrity
# 6315    2013-01-11                                      $ellebrity
# 20070   2018-01-29  '85: The Greatest Team in Pro Football History
# 26340   2018-01-29  '85: The Greatest Team in Pro Football History
# 18016   2017-02-10                                         1 Night
# ...            ...                                             ...
# 21659   2011-03-11                                 When Love Comes
# 13823   2014-11-01                                 Meeting Dr. Sun
# 17054   2014-11-01                                 Meeting Dr. Sun
# 17659   2016-08-12                              Operation Chromite
# 20952   2016-08-12                              Operation Chromite
#
#        vote_average  vote_count
# 9191            5.6          12
# 6315            5.6          12
# 20070           7.5           2
# 26340           7.5           2
# 18016           6.4         107
# ...             ...         ...
# 21659           7.3          10
# 13823           5.4           4
# 17054           5.4           4
# 17659           6.0          86
# 20952           6.0          86
#
# [2016 rows x 9 columns]

# %% [markdown]
# ### The Numbers db

# %%
df1 = pd.read_csv('../Data/tn.movie_budgets.csv', index_col=0)
df.head()
# Out:
#              genre_ids     id original_language  \
# 0      [12, 14, 10751]  12444                en
# 1  [14, 12, 16, 10751]  10191                en
# 2        [12, 28, 878]  10138                en
# 3      [16, 35, 10751]    862                en
# 4        [28, 878, 12]  27205                en
#
#                                  original_title  popularity release_date  \
# 0  Harry Potter and the Deathly Hallows: Part 1      33.533   2010-11-19
# 1                      How to Train Your Dragon      28.734   2010-03-26
# 2                                    Iron Man 2      28.515   2010-05-07
# 3                                     Toy Story      28.005   1995-11-22
# 4                                     Inception      27.920   2010-07-16
#
#                                           title  vote_average  vote_count
# 0  Harry Potter and the Deathly Hallows: Part 1           7.7       10788
# 1                      How to Train Your Dragon           7.7        7610
# 2                                    Iron Man 2           6.8       12368
# 3                                     Toy Story           7.9       10174
# 4                                     Inception           8.3       22186

# %%
df1['movie'].value_counts()
# Out:
# Home                    3
# King Kong               3
# Halloween               3
# Beauty and the Beast    2
# The Gambler             2
#                        ..
# Big Fat Liar            1
# Cats & Dogs             1
# All Eyez on Me          1
# Seabiscuit              1
# Lowriders               1
# Name: movie, Length: 5698, dtype: int64

# %% [markdown]
# ### Joining by movie title

# %%
### FIX ME : Doesn't join on title and movie
budget_and_rating_df = df1.join(df, rsuffix= '_budget', how = 'inner')
budget_and_rating_df.head(20)
# Out:
#    release_date                              movie production_budget  \
# 1  Dec 18, 2009                             Avatar      $425,000,000
# 1  May 29, 2009                                 Up      $175,000,000
# 1   Mar 7, 2014              Mr. Peabody & Sherman      $145,000,000
# 1  Dec 17, 2010                   How Do You Know?      $120,000,000
# 1  Dec 11, 2015            In the Heart of the Sea      $100,000,000
# 1   Jun 8, 2007                   Ocean's Thirteen       $85,000,000
# 1  Nov 26, 2003                           Timeline       $80,000,000
# 1  Aug 21, 2009               Inglourious Basterds       $70,000,000
# 1  Nov 21, 2012                           Red Dawn       $65,000,000
# 1  Nov 26, 1997                Alien: Resurrection       $60,000,000
# 1  May 12, 1995                       Crimson Tide       $55,000,000
# 1  Dec 19, 2008                            Yes Man       $50,000,000
# 1   Mar 3, 2000          What Planet Are You From?       $50,000,000
# 1  Dec 26, 2008                 Revolutionary Road       $45,000,000
# 1  Nov 14, 2014                 Dumb and Dumber To       $40,000,000
# 1   Mar 9, 2012                   A Thousand Words       $40,000,000
# 1  Jul 18, 2008                       Space Chimps       $37,000,000
# 1  Mar 26, 2004                        Jersey Girl       $35,000,000
# 1  Feb 18, 2011  Big Mommas: Like Father, Like Son       $32,000,000
# 1  Sep 22, 1989                         Black Rain       $30,000,000
#
#   domestic_gross worldwide_gross            genre_ids     id  \
# 1   $760,507,625  $2,776,345,279  [14, 12, 16, 10751]  10191
# 1   $293,004,164    $731,463,377  [14, 12, 16, 10751]  10191
# 1   $111,506,430    $269,806,430  [14, 12, 16, 10751]  10191
# 1    $30,212,620     $49,628,177  [14, 12, 16, 10751]  10191
# 1    $25,020,758     $89,693,309  [14, 12, 16, 10751]  10191
# 1   $117,144,465    $311,744,465  [14, 12, 16, 10751]  10191
# 1    $19,480,739     $26,703,184  [14, 12, 16, 10751]  10191
# 1   $120,774,594    $316,915,264  [14, 12, 16, 10751]  10191
# 1    $44,806,783     $48,164,150  [14, 12, 16, 10751]  10191
# 1    $47,795,018    $160,700,000  [14, 12, 16, 10751]  10191
# 1    $91,387,195    $159,387,195  [14, 12, 16, 10751]  10191
# 1    $97,690,976    $225,990,976  [14, 12, 16, 10751]  10191
# 1     $6,291,602      $6,291,602  [14, 12, 16, 10751]  10191
# 1    $22,951,340     $79,604,820  [14, 12, 16, 10751]  10191
# 1    $86,208,010    $156,553,592  [14, 12, 16, 10751]  10191
# 1    $18,450,127     $20,790,486  [14, 12, 16, 10751]  10191
# 1    $30,105,968     $67,029,956  [14, 12, 16, 10751]  10191
# 1    $25,266,129     $37,066,129  [14, 12, 16, 10751]  10191
# 1    $37,915,414     $82,332,450  [14, 12, 16, 10751]  10191
# 1    $45,892,212     $45,892,212  [14, 12, 16, 10751]  10191
#
#   original_language            original_title  popularity release_date_budget  \
# 1                en  How to Train Your Dragon      28.734          2010-03-26
# 1                en  How to Train Your Dragon      28.734          2010-03-26
# 1                en  How to Train Your Dragon      28.734          2010-03-26
# 1                en  How to Train Your Dragon      28.734          2010-03-26
# 1                en  How to Train Your Dragon      28.734          2010-03-26
# 1                en  How to Train Your Dragon      28.734          2010-03-26
# 1                en  How to Train Your Dragon      28.734          2010-03-26
# 1                en  How to Train Your Dragon      28.734          2010-03-26
# 1                en  How to Train Your Dragon      28.734          2010-03-26
# 1                en  How to Train Your Dragon      28.734          2010-03-26
# 1                en  How to Train Your Dragon      28.734          2010-03-26
# 1                en  How to Train Your Dragon      28.734          2010-03-26
# 1                en  How to Train Your Dragon      28.734          2010-03-26
# 1                en  How to Train Your Dragon      28.734          2010-03-26
# 1                en  How to Train Your Dragon      28.734          2010-03-26
# 1                en  How to Train Your Dragon      28.734          2010-03-26
# 1                en  How to Train Your Dragon      28.734          2010-03-26
# 1                en  How to Train Your Dragon      28.734          2010-03-26
# 1                en  How to Train Your Dragon      28.734          2010-03-26
# 1                en  How to Train Your Dragon      28.734          2010-03-26
#
#                       title  vote_average  vote_count
# 1  How to Train Your Dragon           7.7        7610
# 1  How to Train Your Dragon           7.7        7610
# 1  How to Train Your Dragon           7.7        7610
# 1  How to Train Your Dragon           7.7        7610
# 1  How to Train Your Dragon           7.7        7610
# 1  How to Train Your Dragon           7.7        7610
# 1  How to Train Your Dragon           7.7        7610
# 1  How to Train Your Dragon           7.7        7610
# 1  How to Train Your Dragon           7.7        7610
# 1  How to Train Your Dragon           7.7        7610
# 1  How to Train Your Dragon           7.7        7610
# 1  How to Train Your Dragon           7.7        7610
# 1  How to Train Your Dragon           7.7        7610
# 1  How to Train Your Dragon           7.7        7610
# 1  How to Train Your Dragon           7.7        7610
# 1  How to Train Your Dragon           7.7        7610
# 1  How to Train Your Dragon           7.7        7610
# 1  How to Train Your Dragon           7.7        7610
# 1  How to Train Your Dragon           7.7        7610
# 1  How to Train Your Dragon           7.7        7610

# %%
budget_and_rating_df.value_counts()
# Out:
# release_date  movie                    production_budget  domestic_gross  worldwide_gross  genre_ids              id     original_language  original_title             popularity  release_date_budget  title                      vote_average  vote_count
# Sep 9, 2016   When the Bough Breaks    $10,000,000        $29,747,603     $30,768,449      [10749, 35]            25195  en                 Leap Year                  11.821      2010-01-08           Leap Year                  6.7           990           1
# Feb 23, 1996  Rumble in the Bronx      $7,500,000         $32,281,907     $36,238,752      [35, 16, 10751]        9994   en                 The Great Mouse Detective  13.348      1986-07-02           The Great Mouse Detective  7.1           769           1
# Feb 23, 2000  Wonder Boys              $35,000,000        $19,389,454     $33,422,485      [16, 10751]            38757  en                 Tangled                    21.511      2010-11-24           Tangled                    7.5           6407          1
# Feb 23, 2001  3000 Miles to Graceland  $62,000,000        $15,738,632     $18,708,848      [35, 10749]            34806  en                 The Back-Up Plan           15.490      2010-04-23           The Back-Up Plan           6.0           806           1
#               Monkeybone               $75,000,000        $5,409,517      $5,409,517       [80, 18, 9648, 10749]  25376  es                 El secreto de sus ojos     12.531      2010-04-16           The Secret in Their Eyes   7.9           1141          1
#                                                                                                                                                                                                                                                               ..
# May 11, 2018  Life of the Party        $30,000,000        $53,059,911     $65,759,911      [18, 53]               38363  en                 Fair Game                  11.624      2010-05-20           Fair Game                  6.6           384           1
# May 12, 1995  Crimson Tide             $55,000,000        $91,387,195     $159,387,195     [14, 12, 16, 10751]    10191  en                 How to Train Your Dragon   28.734      2010-03-26           How to Train Your Dragon   7.7           7610          1
#               The Perez Family         $11,000,000        $2,794,056      $2,794,056       [28, 12, 14, 878]      19995  en                 Avatar                     26.526      2009-12-18           Avatar                     7.4           18676         1
# May 12, 1999  Trippinâ               $3,000,000         $9,017,070      $9,017,070       [12, 18, 28, 14]       37861  en                 Valhalla Rising            11.260      2010-07-16           Valhalla Rising            6.0           582           1
# Apr 1, 1975   Death Race 2000          $300,000           $0              $0               [53, 80, 27]           43947  en                 I Spit on Your Grave       13.102      2010-10-08           I Spit on Your Grave       6.3           977           1
# Length: 5782, dtype: int64

# %% [markdown]
# ### IMDB db

# %%
#List of Tables
conn = sqlite3.connect("../Data/im.db")
sql_query = """
SELECT name FROM sqlite_master  
WHERE type='table';
"""
pd.read_sql(sql_query,conn)
# Out:
#             name
# 0   movie_basics
# 1      directors
# 2      known_for
# 3     movie_akas
# 4  movie_ratings
# 5        persons
# 6     principals
# 7        writers

# %%
# Basic movie info
q = """
SELECT * FROM movie_basics
"""
movie_basics_pd = pd.read_sql(q, conn)
movie_basics_pd.head()
# Out:
#     movie_id                    primary_title              original_title  \
# 0  tt0063540                        Sunghursh                   Sunghursh
# 1  tt0066787  One Day Before the Rainy Season             Ashad Ka Ek Din
# 2  tt0069049       The Other Side of the Wind  The Other Side of the Wind
# 3  tt0069204                  Sabse Bada Sukh             Sabse Bada Sukh
# 4  tt0100275         The Wandering Soap Opera       La Telenovela Errante
#
#    start_year  runtime_minutes                genres
# 0        2013            175.0    Action,Crime,Drama
# 1        2019            114.0       Biography,Drama
# 2        2018            122.0                 Drama
# 3        2018              NaN          Comedy,Drama
# 4        2017             80.0  Comedy,Drama,Fantasy

# %%
# Ratings
q = """
SELECT * FROM movie_ratings
"""
movie_ratings_pd = pd.read_sql(q, conn)
movie_ratings_pd.head()
# Out:
#      movie_id  averagerating  numvotes
# 0  tt10356526            8.3        31
# 1  tt10384606            8.9       559
# 2   tt1042974            6.4        20
# 3   tt1043726            4.2     50352
# 4   tt1060240            6.5        21

# %% [markdown]
# ### Joining movie information

# %%
# Join movie_basics and movie_ratings tables from IMDB db
# Inner Join on movie_id
# Provides comparison of title, year, genres, and averagerating
# Instantiates the dataframe 'movie_info_pd'
q = """
SELECT * FROM movie_basics JOIN movie_ratings
USING(movie_id)

"""
movie_info_pd = pd.read_sql(q, conn)

# %%
movie_info_pd.head()
# Out:
#     movie_id                    primary_title              original_title  \
# 0  tt0063540                        Sunghursh                   Sunghursh
# 1  tt0066787  One Day Before the Rainy Season             Ashad Ka Ek Din
# 2  tt0069049       The Other Side of the Wind  The Other Side of the Wind
# 3  tt0069204                  Sabse Bada Sukh             Sabse Bada Sukh
# 4  tt0100275         The Wandering Soap Opera       La Telenovela Errante
#
#    start_year  runtime_minutes                genres  averagerating  numvotes
# 0        2013            175.0    Action,Crime,Drama            7.0        77
# 1        2019            114.0       Biography,Drama            7.2        43
# 2        2018            122.0                 Drama            6.9      4517
# 3        2018              NaN          Comedy,Drama            6.1        13
# 4        2017             80.0  Comedy,Drama,Fantasy            6.5       119

# %%
type(movie_basics_pd)
# Out:
# pandas.core.frame.DataFrame

# %%
# Instantiates table movie_aka from IMDB db as dataframe movie_region_pd
q = """
SELECT * FROM movie_akas

"""
movie_region_pd = pd.read_sql(q, conn)
movie_region_pd.head()
# Out:
#     movie_id  ordering                                    title region  \
# 0  tt0369610        10                            Джурасик свят     BG
# 1  tt0369610        11                        Jurashikku warudo     JP
# 2  tt0369610        12  Jurassic World: O Mundo dos Dinossauros     BR
# 3  tt0369610        13                  O Mundo dos Dinossauros     BR
# 4  tt0369610        14                           Jurassic World     FR
#
#   language        types   attributes  is_original_title
# 0       bg         None         None                0.0
# 1     None  imdbDisplay         None                0.0
# 2     None  imdbDisplay         None                0.0
# 3     None         None  short title                0.0
# 4     None  imdbDisplay         None                0.0

# %%
# Imports to query dataframes
from pandasql import sqldf
pysqldf = lambda q: sqldf(q, globals())

# %%
# Testing query import
q = """SELECT
        primary_title
    FROM 
        movie_info_pd info;

"""

# %%
results = pysqldf(q)
results.head()
# Out:
#                      primary_title
# 0                        Sunghursh
# 1  One Day Before the Rainy Season
# 2       The Other Side of the Wind
# 3                  Sabse Bada Sukh
# 4         The Wandering Soap Opera

# %%
# Concatinate dataframes movie_info_pd and movie_region_pd 
# Allows filtering by region
df = movie_info_pd.join(movie_region_pd, rsuffix= '_region_')

# %%
df.head()
# Out:
#     movie_id                    primary_title              original_title  \
# 0  tt0063540                        Sunghursh                   Sunghursh
# 1  tt0066787  One Day Before the Rainy Season             Ashad Ka Ek Din
# 2  tt0069049       The Other Side of the Wind  The Other Side of the Wind
# 3  tt0069204                  Sabse Bada Sukh             Sabse Bada Sukh
# 4  tt0100275         The Wandering Soap Opera       La Telenovela Errante
#
#    start_year  runtime_minutes                genres  averagerating  numvotes  \
# 0        2013            175.0    Action,Crime,Drama            7.0        77
# 1        2019            114.0       Biography,Drama            7.2        43
# 2        2018            122.0                 Drama            6.9      4517
# 3        2018              NaN          Comedy,Drama            6.1        13
# 4        2017             80.0  Comedy,Drama,Fantasy            6.5       119
#
#   movie_id_region_  ordering                                    title region  \
# 0        tt0369610        10                            Джурасик свят     BG
# 1        tt0369610        11                        Jurashikku warudo     JP
# 2        tt0369610        12  Jurassic World: O Mundo dos Dinossauros     BR
# 3        tt0369610        13                  O Mundo dos Dinossauros     BR
# 4        tt0369610        14                           Jurassic World     FR
#
#   language        types   attributes  is_original_title
# 0       bg         None         None                0.0
# 1     None  imdbDisplay         None                0.0
# 2     None  imdbDisplay         None                0.0
# 3     None         None  short title                0.0
# 4     None  imdbDisplay         None                0.0

# %%
# Filter dataframe by region "US"
# As dataframe us_results
q = """SELECT
        *
    FROM 
        df
    WHERE region == "US";

"""

# %%
us_results = pysqldf(q)
us_results.head(15)
# Out:
#      movie_id                       primary_title  \
# 0   tt0176694                  The Tragedy of Man
# 1   tt0262218                   Akakis mogzauroba
# 2   tt0263814                            On kadin
# 3   tt0297400                           Snowblind
# 4   tt0330811                 Regret Not Speaking
# 5   tt0365545                  Nappily Ever After
# 6   tt0365907         A Walk Among the Tombstones
# 7   tt0409847                    Cowboys & Aliens
# 8   tt0425785                 El borde del tiempo
# 9   tt0448694                       Puss in Boots
# 10  tt0458339  Captain America: The First Avenger
# 11  tt0461336                Saving Private Perez
# 12  tt0470936            Hot Country, Cold Winter
# 13  tt0472181                          The Smurfs
# 14  tt0473088                                Stan
#
#                         original_title  start_year  runtime_minutes  \
# 0                  Az ember tragédiája        2011            160.0
# 1                    Akakis mogzauroba        2012             44.0
# 2                             On kadin        2019              NaN
# 3                            Snowblind        2015              NaN
# 4                  Regret Not Speaking        2011              NaN
# 5                   Nappily Ever After        2018             98.0
# 6          A Walk Among the Tombstones        2014            114.0
# 7                     Cowboys & Aliens        2011            119.0
# 8                  El borde del tiempo        2011            100.0
# 9                        Puss in Boots        2011             90.0
# 10  Captain America: The First Avenger        2011            124.0
# 11           Salvando al Soldado Pérez        2011            105.0
# 12              Tak erkir, tsurt dzmer        2016            104.0
# 13                          The Smurfs        2011            103.0
# 14                                Stan        2011              NaN
#
#                         genres  averagerating  numvotes movie_id_region_  \
# 0      Animation,Drama,History            7.8       584        tt0369610
# 1                  Documentary            7.8        22        tt0369610
# 2                        Drama            7.1       100        tt0369610
# 3                  Crime,Drama            6.7        77        tt0369610
# 4                         None            6.2        10        tt0369610
# 5         Comedy,Drama,Romance            6.4      6287        tt0401729
# 6           Action,Crime,Drama            6.5    105116        tt0401729
# 7       Action,Sci-Fi,Thriller            6.0    195889        tt0401729
# 8                        Drama            6.2         6        tt0401729
# 9   Action,Adventure,Animation            6.6    133355        tt1014759
# 10     Action,Adventure,Sci-Fi            6.9    668137        tt1014759
# 11    Adventure,Comedy,Western            6.0      1727        tt1014759
# 12                       Drama            4.0        62       tt10379338
# 13  Adventure,Animation,Comedy            5.5     77577       tt10379338
# 14                      Comedy            8.8        27       tt10446418
#
#     ordering                                       title region language  \
# 0         21                           Jurassic World 3D     US     None
# 1         29                              Jurassic World     US     None
# 2          2                                    Ebb Tide     US     None
# 3         36                            Jurassic Park IV     US     None
# 4         44                             Jurassic Park 4     US     None
# 5         11                         John Carter of Mars     US     None
# 6         12                          A Princess of Mars     US     None
# 7          2                                 John Carter     US     None
# 8          5                                     Barsoom     US     None
# 9         23  Alice in Wonderland: An IMAX 3D Experience     US     None
# 10        37                         Alice in Wonderland     US     None
# 11         6                                       Alice     US     None
# 12         1                              Guys Night Out     US     None
# 13         3                            Random Night Out     US     None
# 14         3                                    The Icon     US     None
#
#           types                  attributes  is_original_title
# 0          None                 3-D version                0.0
# 1          None                        None                0.0
# 2          None          fake working title                0.0
# 3       working                        None                0.0
# 4          None  informal alternative title                0.0
# 5       working                        None                0.0
# 6       working                        None                0.0
# 7          None                        None                0.0
# 8          None          fake working title                0.0
# 9          None                IMAX version                0.0
# 10         None                        None                0.0
# 11         None       original script title                0.0
# 12  imdbDisplay                        None                0.0
# 13         None                        None                0.0
# 14  alternative                        None                0.0

# %%
# Checking year to find cut off for recent, relevant entries
us_results['start_year'].value_counts()
# Out:
# 2015    1300
# 2016    1285
# 2014    1276
# 2017    1248
# 2013    1162
# 2012    1149
# 2018    1100
# 2011    1084
# 2010    1057
# 2019     326
# Name: start_year, dtype: int64

# %%
# Ordering by year
q = """SELECT
        *
    FROM 
        modern_movies
    ORDER BY start_year;

"""

# %%
modern_movies = pysqldf(q)
modern_movies.head(15)
# Out:
#      movie_id              primary_title             original_title  \
# 0   tt0297400                  Snowblind                  Snowblind
# 1   tt0850678               Jackson Arms               Jackson Arms
# 2   tt1018728  Heart Like a Hand Grenade  Heart Like a Hand Grenade
# 3   tt1196939                     Gracie                     Gracie
# 4   tt1226766    The Great Gilly Hopkins    The Great Gilly Hopkins
# 5   tt1254322              The Girl King              The Girl King
# 6   tt1321390                  Greyscale                  Greyscale
# 7   tt1365050        Beasts of No Nation        Beasts of No Nation
# 8   tt1369667            Me and Kaminski           Ich und Kaminski
# 9   tt1390411    In the Heart of the Sea    In the Heart of the Sea
# 10  tt1524575          The Vatican Tapes          The Vatican Tapes
# 11  tt1529265              Grave Reality              Grave Reality
# 12  tt1577040                       Alto                       Alto
# 13  tt1598642            Z for Zachariah            Z for Zachariah
# 14  tt1629242  Careful What You Wish For  Careful What You Wish For
#
#     start_year  runtime_minutes                      genres  averagerating  \
# 0         2015              NaN                 Crime,Drama            6.7
# 1         2015             90.0                     Romance            6.1
# 2         2015             96.0                 Documentary            7.4
# 3         2015             71.0         Crime,Drama,Fantasy            7.0
# 4         2015             99.0         Comedy,Drama,Family            6.5
# 5         2015            106.0     Biography,Drama,History            5.9
# 6         2015            105.0          Action,Crime,Drama            8.0
# 7         2015            137.0                   Drama,War            7.8
# 8         2015            124.0                Comedy,Drama            6.7
# 9         2015            122.0  Action,Adventure,Biography            6.9
# 10        2015             91.0             Horror,Thriller            5.0
# 11        2015             75.0                      Horror            6.8
# 12        2015            101.0       Comedy,Family,Romance            4.9
# 13        2015             98.0       Drama,Sci-Fi,Thriller            6.0
# 14        2015             91.0              Drama,Thriller            5.7
#
#     numvotes movie_id_region_  ordering  \
# 0         77        tt0369610        36
# 1         15        tt1248300         1
# 2        335        tt1422800        11
# 3         31        tt1822325         1
# 4       3884        tt1854545         1
# 5       3116        tt1913193         1
# 6         45        tt2057486         1
# 7      63797        tt2124845         1
# 8       1125        tt2129871         1
# 9     108628        tt2197094         1
# 10     14822        tt1646972         1
# 11         9        tt1670991         1
# 12       473        tt1904833         1
# 13     25429        tt2084839         1
# 14      6659        tt1397514        35
#
#                                                 title region language  \
# 0                                    Jurassic Park IV     US     None
# 1                                             Rollers     US     None
# 2                                                Wake     US     None
# 3                                     The Black Belle     US     None
# 4                                      Jerseyboy Hero     US     None
# 5                                            Utopians     US     None
# 6                                       The Lazy Ones     US     None
# 7                                           Luna Mesa     US     None
# 8                                 Absolute Corruption     US     None
# 9                                            Vertical     US     None
# 10                                            Jasmine     US     None
# 11                                   Grooming Giselle     US     None
# 12                       Akkarakazhchakal - The Movie     US     None
# 13                    Getting Up: The TEMPT ONE Story     US     None
# 14  Untitled Journey to the Center of the Earth Se...     US     None
#
#        types attributes  is_original_title
# 0    working       None                0.0
# 1       None       None                0.0
# 2   festival       None                0.0
# 3       None       None                0.0
# 4       None       None                0.0
# 5       None       None                0.0
# 6       None       None                0.0
# 7       None       None                0.0
# 8       None       None                0.0
# 9       None       None                0.0
# 10      None       None                0.0
# 11      None       None                0.0
# 12      None       None                0.0
# 13      None       None                0.0
# 14   working       None                0.0

# %%
# Checking values of filtered and ordered data.
modern_movies['start_year'].value_counts()
# Out:
# 2015    1300
# 2016    1285
# 2017    1248
# 2018    1100
# 2019     326
# Name: start_year, dtype: int64

# %%
# Initial statistics of modern_movies
modern_movies.describe()
# Out:
#         start_year  runtime_minutes  averagerating       numvotes  \
# count  5259.000000      4680.000000    5259.000000    5259.000000
# mean   2016.594410        95.417094       6.383856    2591.081384
# std       1.235327        29.470891       1.490126   24131.393862
# min    2015.000000         4.000000       1.000000       5.000000
# 25%    2016.000000        82.000000       5.500000      14.000000
# 50%    2017.000000        92.000000       6.500000      49.000000
# 75%    2018.000000       105.000000       7.400000     258.000000
# max    2019.000000      1100.000000       9.800000  820847.000000
#
#           ordering  is_original_title
# count  5259.000000             5259.0
# mean      3.176459                0.0
# std       5.531820                0.0
# min       1.000000                0.0
# 25%       1.000000                0.0
# 50%       1.000000                0.0
# 75%       3.000000                0.0
# max      52.000000                0.0

# %%
pd.plotting.scatter_matrix(modern_movies);
# Out:
# C:\Users\dabutt\Anaconda3\envs\learn-env\lib\site-packages\pandas\plotting\_matplotlib\misc.py:80: UserWarning: Attempting to set identical left == right == 0.0 results in singular transformations; automatically expanding.
#   ax.set_xlim(boundaries_list[j])
# C:\Users\dabutt\Anaconda3\envs\learn-env\lib\site-packages\pandas\plotting\_matplotlib\misc.py:81: UserWarning: Attempting to set identical bottom == top == 0.0 results in singular transformations; automatically expanding.
#   ax.set_ylim(boundaries_list[i])
# C:\Users\dabutt\Anaconda3\envs\learn-env\lib\site-packages\pandas\plotting\_matplotlib\misc.py:71: UserWarning: Attempting to set identical left == right == 0.0 results in singular transformations; automatically expanding.
#   ax.set_xlim(boundaries_list[i])

# %%
# Limiting us_results to movies started in the last 5 years
# As dataframe modern_movies
modern_movies = us_results[us_results['start_year'] >= 2015]
modern_movies.head()
# Out:
#      movie_id             primary_title          original_title  start_year  \
# 2   tt0263814                  On kadin                On kadin        2019
# 3   tt0297400                 Snowblind               Snowblind        2015
# 5   tt0365545        Nappily Ever After      Nappily Ever After        2018
# 12  tt0470936  Hot Country, Cold Winter  Tak erkir, tsurt dzmer        2016
# 17  tt0491175                Suburbicon              Suburbicon        2017
#
#     runtime_minutes                genres  averagerating  numvotes  \
# 2               NaN                 Drama            7.1       100
# 3               NaN           Crime,Drama            6.7        77
# 5              98.0  Comedy,Drama,Romance            6.4      6287
# 12            104.0                 Drama            4.0        62
# 17            105.0    Comedy,Crime,Drama            5.6     31294
#
#    movie_id_region_  ordering                title region language  \
# 2         tt0369610         2             Ebb Tide     US     None
# 3         tt0369610        36     Jurassic Park IV     US     None
# 5         tt0401729        11  John Carter of Mars     US     None
# 12       tt10379338         1       Guys Night Out     US     None
# 17        tt1189904         1      Small Town Hero     US     None
#
#           types          attributes  is_original_title
# 2          None  fake working title                0.0
# 3       working                None                0.0
# 5       working                None                0.0
# 12  imdbDisplay                None                0.0
# 17         None                None                0.0

# %% [markdown]
# ### Fix Format

# %%
import pandas as pd
import sqlite3
import re

# %% [markdown]
# ### Explore links to combine tables

# %% [markdown]
# ### Load tables from Data Sources

# %%
# load tables from the sql db

# connect  to db
conn = sqlite3.connect("../Data/im.db")

# load movie basics table
movie_basics_df = pd.read_sql("SELECT * FROM movie_basics;", conn)

# load movie ratings table
movie_ratings_df = pd.read_sql("SELECT * FROM movie_ratings;", conn)

# load movie aka table
movie_akas_df = pd.read_sql("SELECT * FROM movie_akas;", conn)

# %% [markdown]
# ### Load data from files

# %%
# load movie gross data
movie_gross = pd.read_csv("../Data/bom.movie_gross.csv")

# load movie budget/gross data
movie_budgets = pd.read_csv("../Data/tn.movie_budgets.csv")

# %% [markdown]
# ### Preview tables

# %%
movie_budgets
# Out:
#       id  release_date                                        movie  \
# 0      1  Dec 18, 2009                                       Avatar
# 1      2  May 20, 2011  Pirates of the Caribbean: On Stranger Tides
# 2      3   Jun 7, 2019                                 Dark Phoenix
# 3      4   May 1, 2015                      Avengers: Age of Ultron
# 4      5  Dec 15, 2017            Star Wars Ep. VIII: The Last Jedi
# ...   ..           ...                                          ...
# 5777  78  Dec 31, 2018                                       Red 11
# 5778  79   Apr 2, 1999                                    Following
# 5779  80  Jul 13, 2005                Return to the Land of Wonders
# 5780  81  Sep 29, 2015                         A Plague So Pleasant
# 5781  82   Aug 5, 2005                            My Date With Drew
#
#      production_budget domestic_gross worldwide_gross
# 0         $425,000,000   $760,507,625  $2,776,345,279
# 1         $410,600,000   $241,063,875  $1,045,663,875
# 2         $350,000,000    $42,762,350    $149,762,350
# 3         $330,600,000   $459,005,868  $1,403,013,963
# 4         $317,000,000   $620,181,382  $1,316,721,747
# ...                ...            ...             ...
# 5777            $7,000             $0              $0
# 5778            $6,000        $48,482        $240,495
# 5779            $5,000         $1,338          $1,338
# 5780            $1,400             $0              $0
# 5781            $1,100       $181,041        $181,041
#
# [5782 rows x 6 columns]

# %%
movie_gross
# Out:
#                                             title      studio  domestic_gross  \
# 0                                     Toy Story 3          BV     415000000.0
# 1                      Alice in Wonderland (2010)          BV     334200000.0
# 2     Harry Potter and the Deathly Hallows Part 1          WB     296000000.0
# 3                                       Inception          WB     292600000.0
# 4                             Shrek Forever After        P/DW     238700000.0
# ...                                           ...         ...             ...
# 3382                                    The Quake       Magn.          6200.0
# 3383                  Edward II (2018 re-release)          FM          4800.0
# 3384                                     El Pacto        Sony          2500.0
# 3385                                     The Swan  Synergetic          2400.0
# 3386                            An Actor Prepares       Grav.          1700.0
#
#      foreign_gross  year
# 0        652000000  2010
# 1        691300000  2010
# 2        664300000  2010
# 3        535700000  2010
# 4        513900000  2010
# ...            ...   ...
# 3382           NaN  2018
# 3383           NaN  2018
# 3384           NaN  2018
# 3385           NaN  2018
# 3386           NaN  2018
#
# [3387 rows x 5 columns]

# %%
movie_basics_df
# Out:
#          movie_id                                primary_title  \
# 0       tt0063540                                    Sunghursh
# 1       tt0066787              One Day Before the Rainy Season
# 2       tt0069049                   The Other Side of the Wind
# 3       tt0069204                              Sabse Bada Sukh
# 4       tt0100275                     The Wandering Soap Opera
# ...           ...                                          ...
# 146139  tt9916538                          Kuambil Lagi Hatiku
# 146140  tt9916622  Rodolpho Teóphilo - O Legado de um Pioneiro
# 146141  tt9916706                              Dankyavar Danka
# 146142  tt9916730                                       6 Gunn
# 146143  tt9916754               Chico Albuquerque - Revelações
#
#                                      original_title  start_year  \
# 0                                         Sunghursh        2013
# 1                                   Ashad Ka Ek Din        2019
# 2                        The Other Side of the Wind        2018
# 3                                   Sabse Bada Sukh        2018
# 4                             La Telenovela Errante        2017
# ...                                             ...         ...
# 146139                          Kuambil Lagi Hatiku        2019
# 146140  Rodolpho Teóphilo - O Legado de um Pioneiro        2015
# 146141                              Dankyavar Danka        2013
# 146142                                       6 Gunn        2017
# 146143               Chico Albuquerque - Revelações        2013
#
#         runtime_minutes                genres
# 0                 175.0    Action,Crime,Drama
# 1                 114.0       Biography,Drama
# 2                 122.0                 Drama
# 3                   NaN          Comedy,Drama
# 4                  80.0  Comedy,Drama,Fantasy
# ...                 ...                   ...
# 146139            123.0                 Drama
# 146140              NaN           Documentary
# 146141              NaN                Comedy
# 146142            116.0                  None
# 146143              NaN           Documentary
#
# [146144 rows x 6 columns]

# %%
movie_ratings_df
# Out:
#          movie_id  averagerating  numvotes
# 0      tt10356526            8.3        31
# 1      tt10384606            8.9       559
# 2       tt1042974            6.4        20
# 3       tt1043726            4.2     50352
# 4       tt1060240            6.5        21
# ...           ...            ...       ...
# 73851   tt9805820            8.1        25
# 73852   tt9844256            7.5        24
# 73853   tt9851050            4.7        14
# 73854   tt9886934            7.0         5
# 73855   tt9894098            6.3       128
#
# [73856 rows x 3 columns]

# %%
movie_akas_df
# Out:
#          movie_id  ordering                                    title region  \
# 0       tt0369610        10                            Джурасик свят     BG
# 1       tt0369610        11                        Jurashikku warudo     JP
# 2       tt0369610        12  Jurassic World: O Mundo dos Dinossauros     BR
# 3       tt0369610        13                  O Mundo dos Dinossauros     BR
# 4       tt0369610        14                           Jurassic World     FR
# ...           ...       ...                                      ...    ...
# 331698  tt9827784         2                       Sayonara kuchibiru   None
# 331699  tt9827784         3                            Farewell Song    XWW
# 331700  tt9880178         1                              La atención   None
# 331701  tt9880178         2                              La atención     ES
# 331702  tt9880178         3                            The Attention    XWW
#
#        language        types   attributes  is_original_title
# 0            bg         None         None                0.0
# 1          None  imdbDisplay         None                0.0
# 2          None  imdbDisplay         None                0.0
# 3          None         None  short title                0.0
# 4          None  imdbDisplay         None                0.0
# ...         ...          ...          ...                ...
# 331698     None     original         None                1.0
# 331699       en  imdbDisplay         None                0.0
# 331700     None     original         None                1.0
# 331701     None         None         None                0.0
# 331702       en  imdbDisplay         None                0.0
#
# [331703 rows x 8 columns]

# %% [markdown]
# ### Combine SQL tables

# %%
# join tables on movie_id
df = movie_ratings_df.merge(movie_basics_df, how="inner", on="movie_id")
df = df.merge(movie_akas_df, how="inner", on="movie_id")
df
# Out:
#          movie_id  averagerating  numvotes  \
# 0       tt1042974            6.4        20
# 1       tt1042974            6.4        20
# 2       tt1042974            6.4        20
# 3       tt1043726            4.2     50352
# 4       tt1043726            4.2     50352
# ...           ...            ...       ...
# 261801  tt9691896            6.3        21
# 261802  tt9844256            7.5        24
# 261803  tt9844256            7.5        24
# 261804  tt9844256            7.5        24
# 261805  tt9844256            7.5        24
#
#                                             primary_title  \
# 0                                               Just Inès
# 1                                               Just Inès
# 2                                               Just Inès
# 3                                  The Legend of Hercules
# 4                                  The Legend of Hercules
# ...                                                   ...
# 261801                                                Out
# 261802  Code Geass: Lelouch of the Rebellion - Glorifi...
# 261803  Code Geass: Lelouch of the Rebellion - Glorifi...
# 261804  Code Geass: Lelouch of the Rebellion - Glorifi...
# 261805  Code Geass: Lelouch of the Rebellion - Glorifi...
#
#                                           original_title  start_year  \
# 0                                              Just Inès        2010
# 1                                              Just Inès        2010
# 2                                              Just Inès        2010
# 3                                 The Legend of Hercules        2014
# 4                                 The Legend of Hercules        2014
# ...                                                  ...         ...
# 261801                                        Coming Out        2018
# 261802  Code Geass: Lelouch of the Rebellion Episode III        2018
# 261803  Code Geass: Lelouch of the Rebellion Episode III        2018
# 261804  Code Geass: Lelouch of the Rebellion Episode III        2018
# 261805  Code Geass: Lelouch of the Rebellion Episode III        2018
#
#         runtime_minutes                    genres  ordering  \
# 0                  90.0                     Drama         1
# 1                  90.0                     Drama         2
# 2                  90.0                     Drama         3
# 3                  99.0  Action,Adventure,Fantasy        10
# 4                  99.0  Action,Adventure,Fantasy        11
# ...                 ...                       ...       ...
# 261801             64.0               Documentary         4
# 261802            120.0   Action,Animation,Sci-Fi         1
# 261803            120.0   Action,Animation,Sci-Fi         2
# 261804            120.0   Action,Animation,Sci-Fi         3
# 261805            120.0   Action,Animation,Sci-Fi         4
#
#                                                     title region language  \
# 0                                               Just Inès   None     None
# 1                                               Samo Ines     RS     None
# 2                                               Just Inès     GB     None
# 3                                  The Legend of Hercules   None     None
# 4                               Hércules - A Lenda Começa     PT     None
# ...                                                   ...    ...      ...
# 261801                                         Coming Out   None     None
# 261802   Code Geass: Lelouch of the Rebellion Episode III     JP     None
# 261803   Code Geass: Lelouch of the Rebellion Episode III   None     None
# 261804  Code Geass: Lelouch of the Rebellion - Glorifi...    XWW       en
# 261805     Code Geass: Lelouch of the Rebellion - Emperor    XWW       en
#
#               types attributes  is_original_title
# 0          original       None                1.0
# 1       imdbDisplay       None                0.0
# 2              None       None                0.0
# 3          original       None                1.0
# 4       imdbDisplay       None                0.0
# ...             ...        ...                ...
# 261801     original       None                1.0
# 261802         None       None                0.0
# 261803     original       None                1.0
# 261804  imdbDisplay       None                0.0
# 261805  imdbDisplay       None                0.0
#
# [261806 rows x 15 columns]

# %% [markdown]
# ### Keep only US Movies

# %%
# find the tag for US region
df["region"].unique()
# Out:
# array([None, 'RS', 'GB', 'PT', 'JP', 'AL', 'HR', 'VN', 'IT', 'GR', 'UA',
#        'RO', 'US', 'CA', 'CL', 'MX', 'RU', 'TR', 'IL', 'AR', 'PE', 'FR',
#        'ES', 'BR', 'PL', 'BG', 'HU', 'VE', 'SE', 'XWW', 'XEU', 'SI', 'UY',
#        'FI', 'DE', 'PH', 'NO', 'DK', 'EE', 'BE', 'LT', 'CO', 'CZ', 'AT',
#        'GE', 'IE', 'ZA', 'BA', 'LV', 'AU', 'LU', 'IN', 'KR', 'IR', 'NL',
#        'DZ', 'CN', 'NZ', 'ID', 'MY', 'JO', 'RW', 'EG', 'CH', 'LI', 'TH',
#        'BF', 'CSXX', 'SG', 'NP', 'SK', 'BD', 'PA', 'KE', 'PK', 'PS', 'HK',
#        'MK', 'KZ', 'TW', 'LK', 'IS', 'MW', 'DO', 'BO', 'PY', 'SL', 'AZ',
#        'AF', 'AE', 'PR', 'CU', 'NG', 'IQ', 'AM', 'CY', 'GU', 'HN', 'XAS',
#        'TN', 'BY', 'SA', 'HT', 'MT', 'BH', 'KH', 'KG', 'FO', 'SV', 'XSA',
#        'GT', 'LB', 'BT', 'CR', 'XKV', 'UZ', 'MA', 'ME', 'LA', 'SB', 'XKO',
#        'SY', 'TZ', 'QA', 'MN', 'EC', 'JM', 'NE', 'AN', 'MV', 'TT', 'ET',
#        'CF', 'CM', 'MM', 'TJ', 'SM', 'MD', 'GW', 'KW', 'AD', 'BB', 'MZ',
#        'BS', 'SO', 'BZ', 'IM', 'MC', 'AW', 'UG', 'BN', 'MH', 'AO', 'GH',
#        'ZM', 'GP', 'NI', 'CSHH', 'SUHH', 'CV', 'SN', 'TD', 'PG', 'MU',
#        'XYU', 'GL', 'CG', 'MQ', 'LY', 'BJ', 'GM', 'GA', 'CI', 'ML', 'MO',
#        'CD', 'VI', 'TL', 'MG', 'KP', 'SZ', 'YE', 'BM', 'FJ', 'SR', 'OM',
#        'XWG', 'AG', 'PF', 'XNA', 'ZW', 'MR', 'TO', 'NC', 'SD', 'VC', 'TM'],
#       dtype=object)

# %%
us_movies = df[df["region"]=="US"]
us_movies
# Out:
#          movie_id  averagerating  numvotes             primary_title  \
# 14      tt1043726            4.2     50352    The Legend of Hercules
# 26      tt1043726            4.2     50352    The Legend of Hercules
# 29      tt1043726            4.2     50352    The Legend of Hercules
# 42      tt1094666            7.0      1613                The Hammer
# 45      tt1094666            7.0      1613                The Hammer
# ...           ...            ...       ...                       ...
# 261737  tt9165332            7.4       710              Chitralahari
# 261760  tt9382596            4.1       293  The Car: Road to Revenge
# 261761  tt9382596            4.1       293  The Car: Road to Revenge
# 261762  tt9382596            4.1       293  The Car: Road to Revenge
# 261778  tt9558612            3.7      4057          PM Narendra Modi
#
#                   original_title  start_year  runtime_minutes  \
# 14        The Legend of Hercules        2014             99.0
# 26        The Legend of Hercules        2014             99.0
# 29        The Legend of Hercules        2014             99.0
# 42                        Hamill        2010            108.0
# 45                        Hamill        2010            108.0
# ...                          ...         ...              ...
# 261737              Chitralahari        2019            131.0
# 261760  The Car: Road to Revenge        2019             89.0
# 261761  The Car: Road to Revenge        2019             89.0
# 261762  The Car: Road to Revenge        2019             89.0
# 261778          PM Narendra Modi        2019            136.0
#
#                           genres  ordering                        title  \
# 14      Action,Adventure,Fantasy        20       The Legend of Hercules
# 26      Action,Adventure,Fantasy        31    Untitled Hercules Project
# 29      Action,Adventure,Fantasy         5  Hercules: The Legend Begins
# 42         Biography,Drama,Sport         4                       Hamill
# 45         Biography,Drama,Sport         7                   The Hammer
# ...                          ...       ...                          ...
# 261737                     Drama         2                 Chitralahari
# 261760    Action,Horror,Thriller         1   The Car 2: Road to Revenge
# 261761    Action,Horror,Thriller         2                    The Car 2
# 261762    Action,Horror,Thriller         3     The Car: Road to Revenge
# 261778           Biography,Drama         1             PM Narendra Modi
#
#        region language        types attributes  is_original_title
# 14         US     None         None       None                0.0
# 26         US     None      working       None                0.0
# 29         US     None      working       None                0.0
# 42         US     None     festival       None                0.0
# 45         US     None  imdbDisplay       None                0.0
# ...       ...      ...          ...        ...                ...
# 261737     US       en  imdbDisplay       None                0.0
# 261760     US     None      working       None                0.0
# 261761     US     None      working       None                0.0
# 261762     US     None         None       None                0.0
# 261778     US       en  imdbDisplay       None                0.0
#
# [30194 rows x 15 columns]

# %%
us_movies["movie_id"].nunique()
# Out:
# 26654

# %%
# keep only 1 entry for each movie id
us_movies = us_movies.drop_duplicates(subset=["movie_id"])
us_movies
# Out:
#          movie_id  averagerating  numvotes             primary_title  \
# 14      tt1043726            4.2     50352    The Legend of Hercules
# 42      tt1094666            7.0      1613                The Hammer
# 64      tt1161457            4.2       148                Vanquisher
# 76      tt1171222            5.1      8296             Baggage Claim
# 85      tt1174693            5.8      2381       The Four-Faced Liar
# ...           ...            ...       ...                       ...
# 261715  tt8948790            9.0      1778                    Jersey
# 261734  tt9127488            9.3        10                    Postal
# 261737  tt9165332            7.4       710              Chitralahari
# 261760  tt9382596            4.1       293  The Car: Road to Revenge
# 261778  tt9558612            3.7      4057          PM Narendra Modi
#
#                   original_title  start_year  runtime_minutes  \
# 14        The Legend of Hercules        2014             99.0
# 42                        Hamill        2010            108.0
# 64                The Vanquisher        2016             90.0
# 76                 Baggage Claim        2013             96.0
# 85           The Four-Faced Liar        2010             87.0
# ...                          ...         ...              ...
# 261715                    Jersey        2019            157.0
# 261734                    Postal        2019             77.0
# 261737              Chitralahari        2019            131.0
# 261760  The Car: Road to Revenge        2019             89.0
# 261778          PM Narendra Modi        2019            136.0
#
#                           genres  ordering                       title region  \
# 14      Action,Adventure,Fantasy        20      The Legend of Hercules     US
# 42         Biography,Drama,Sport         4                      Hamill     US
# 64       Action,Adventure,Sci-Fi         1                  Vanquisher     US
# 76                        Comedy         5               Baggage Claim     US
# 85          Comedy,Drama,Romance         5         The Four-Faced Liar     US
# ...                          ...       ...                         ...    ...
# 261715               Drama,Sport         3                      Jersey     US
# 261734                    Comedy         2                      Postal     US
# 261737                     Drama         2                Chitralahari     US
# 261760    Action,Horror,Thriller         1  The Car 2: Road to Revenge     US
# 261778           Biography,Drama         1            PM Narendra Modi     US
#
#        language        types attributes  is_original_title
# 14         None         None       None                0.0
# 42         None     festival       None                0.0
# 64         None         None  new title                0.0
# 76         None         None       None                0.0
# 85         None         None       None                0.0
# ...         ...          ...        ...                ...
# 261715       en  imdbDisplay       None                0.0
# 261734     None         None       None                0.0
# 261737       en  imdbDisplay       None                0.0
# 261760     None      working       None                0.0
# 261778       en  imdbDisplay       None                0.0
#
# [26654 rows x 15 columns]

# %% [markdown]
# ### Add in gross numbers

# %% [markdown]
# ### Clean movie title info for merging
# * all lowercase
# * keep only alpha-numeric values
# * remove spaces

# %%
movie_budgets = pd.read_csv("../Data/tn.movie_budgets.csv")
movie_budgets.head()
# Out:
#    id  release_date                                        movie  \
# 0   1  Dec 18, 2009                                       Avatar
# 1   2  May 20, 2011  Pirates of the Caribbean: On Stranger Tides
# 2   3   Jun 7, 2019                                 Dark Phoenix
# 3   4   May 1, 2015                      Avengers: Age of Ultron
# 4   5  Dec 15, 2017            Star Wars Ep. VIII: The Last Jedi
#
#   production_budget domestic_gross worldwide_gross
# 0      $425,000,000   $760,507,625  $2,776,345,279
# 1      $410,600,000   $241,063,875  $1,045,663,875
# 2      $350,000,000    $42,762,350    $149,762,350
# 3      $330,600,000   $459,005,868  $1,403,013,963
# 4      $317,000,000   $620,181,382  $1,316,721,747

# %%
# use RegEx to keep only alpha-numeric values, remove spaces and make all letters lowercase 
#us_movies["title"] = us_movies["title"].map(lambda x: re.sub(r'[^A-Za-z0-9 ]+', '', x).lower())
us_movies["title"] = us_movies["title"].map(lambda x: re.sub(r'[^A-Za-z0-9]+', '', x).lower())
movie_budgets["movie"] = movie_budgets["movie"].map(lambda x: re.sub(r'[^A-Za-z0-9]+', '', x).lower())
movie_gross["title"] = movie_gross["title"].map(lambda x: re.sub(r'[^A-Za-z0-9]+', '', x).lower())
# Out:
# <ipython-input-109-006c2fb176b4>:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   us_movies["title"] = us_movies["title"].map(lambda x: re.sub(r'[^A-Za-z0-9]+', '', x).lower())

# %%
# rename columns to match for merging
movie_budgets.rename(columns={"movie": "title", "domestic_gross": "domestic_gross_movie_budgets",
                              "worldwide_gross": "worldwide_gross_movie_budgets"}, inplace=True)

movie_gross.rename(columns={"domestic_gross": "domestic_gross_movie_gross", 
                            "foreign_gross": "foreign_gross_movie_gross"}, inplace=True)

# %%
# combine tables
final_gross_df1 = us_movies.merge(movie_budgets, on="title", how="inner")
final_gross_df1
# Out:
#        movie_id  averagerating  numvotes                     primary_title  \
# 0     tt1043726            4.2     50352            The Legend of Hercules
# 1     tt1171222            5.1      8296                     Baggage Claim
# 2     tt1210166            7.6    326657                         Moneyball
# 3     tt1212419            6.5     87288                         Hereafter
# 4     tt6096334            6.4         5                        Here After
# ...         ...            ...       ...                               ...
# 1684  tt2592614            5.6     74979  Resident Evil: The Final Chapter
# 1685  tt2612800            5.7        37                           Sisters
# 1686  tt2704998            7.0    163279                        Game Night
# 1687  tt3111864            5.0       102                            8 Days
# 1688  tt3125324            6.9     14122                 Beyond the Lights
#
#                         original_title  start_year  runtime_minutes  \
# 0               The Legend of Hercules        2014             99.0
# 1                        Baggage Claim        2013             96.0
# 2                            Moneyball        2011            133.0
# 3                            Hereafter        2010            129.0
# 4                           Here After        2018             71.0
# ...                                ...         ...              ...
# 1684  Resident Evil: The Final Chapter        2016            107.0
# 1685                        Schwestern        2013             84.0
# 1686                        Game Night        2018            100.0
# 1687                            8 Days        2014             90.0
# 1688                 Beyond the Lights        2014            116.0
#
#                         genres  ordering                        title region  \
# 0     Action,Adventure,Fantasy        20          thelegendofhercules     US
# 1                       Comedy         5                 baggageclaim     US
# 2        Biography,Drama,Sport        14                    moneyball     US
# 3        Drama,Fantasy,Romance         4                    hereafter     US
# 4                  Documentary         1                    hereafter     US
# ...                        ...       ...                          ...    ...
# 1684      Action,Horror,Sci-Fi         2  residentevilthefinalchapter     US
# 1685                     Drama         2                      sisters     US
# 1686       Action,Comedy,Crime        15                    gamenight     US
# 1687            Drama,Thriller         1                        8days     US
# 1688       Drama,Music,Romance         5              beyondthelights     US
#
#      language        types attributes  is_original_title  id  release_date  \
# 0        None         None       None                0.0  42  Jan 10, 2014
# 1        None         None       None                0.0  38  Sep 27, 2013
# 2        None  imdbDisplay       None                0.0  15  Sep 23, 2011
# 3        None         None       None                0.0  61  Oct 15, 2010
# 4        None         None       None                0.0  61  Oct 15, 2010
# ...       ...          ...        ...                ...  ..           ...
# 1684     None         None       None                0.0  84  Jan 27, 2017
# 1685     None  imdbDisplay       None                0.0  57  Dec 18, 2015
# 1686     None  imdbDisplay       None                0.0  94  Feb 23, 2018
# 1687     None         None       None                0.0  48  Oct 13, 2015
# 1688     None         None       None                0.0  16  Nov 14, 2014
#
#      production_budget domestic_gross_movie_budgets  \
# 0          $70,000,000                  $18,848,538
# 1           $8,500,000                  $21,569,509
# 2          $50,000,000                  $75,605,492
# 3          $50,000,000                  $32,746,941
# 4          $50,000,000                  $32,746,941
# ...                ...                          ...
# 1684       $40,000,000                  $26,844,692
# 1685       $30,000,000                  $87,044,645
# 1686       $37,000,000                  $69,179,066
# 1687        $2,500,000                           $0
# 1688        $7,000,000                  $14,618,727
#
#      worldwide_gross_movie_budgets
# 0                      $58,953,319
# 1                      $22,885,836
# 2                     $111,300,835
# 3                     $108,660,270
# 4                     $108,660,270
# ...                            ...
# 1684                  $314,101,190
# 1685                  $106,030,660
# 1686                  $117,378,084
# 1687                            $0
# 1688                   $14,618,727
#
# [1689 rows x 20 columns]

# %%
final_gross_df2 = us_movies.merge(movie_gross, on="title", how="inner")
final_gross_df2
# Out:
#        movie_id  averagerating  numvotes                     primary_title  \
# 0     tt1043726            4.2     50352            The Legend of Hercules
# 1     tt1171222            5.1      8296                     Baggage Claim
# 2     tt1210166            7.6    326657                         Moneyball
# 3     tt1212419            6.5     87288                         Hereafter
# 4     tt6096334            6.4         5                        Here After
# ...         ...            ...       ...                               ...
# 1562  tt2592614            5.6     74979  Resident Evil: The Final Chapter
# 1563  tt2612800            5.7        37                           Sisters
# 1564  tt2704998            7.0    163279                        Game Night
# 1565  tt7008872            7.0     18768                        Boy Erased
# 1566  tt7315484            5.2     22399                       The Silence
#
#                         original_title  start_year  runtime_minutes  \
# 0               The Legend of Hercules        2014             99.0
# 1                        Baggage Claim        2013             96.0
# 2                            Moneyball        2011            133.0
# 3                            Hereafter        2010            129.0
# 4                           Here After        2018             71.0
# ...                                ...         ...              ...
# 1562  Resident Evil: The Final Chapter        2016            107.0
# 1563                        Schwestern        2013             84.0
# 1564                        Game Night        2018            100.0
# 1565                        Boy Erased        2018            115.0
# 1566                       The Silence        2019             90.0
#
#                         genres  ordering                        title region  \
# 0     Action,Adventure,Fantasy        20          thelegendofhercules     US
# 1                       Comedy         5                 baggageclaim     US
# 2        Biography,Drama,Sport        14                    moneyball     US
# 3        Drama,Fantasy,Romance         4                    hereafter     US
# 4                  Documentary         1                    hereafter     US
# ...                        ...       ...                          ...    ...
# 1562      Action,Horror,Sci-Fi         2  residentevilthefinalchapter     US
# 1563                     Drama         2                      sisters     US
# 1564       Action,Comedy,Crime        15                    gamenight     US
# 1565           Biography,Drama        16                    boyerased     US
# 1566           Horror,Thriller         5                   thesilence     US
#
#      language        types attributes  is_original_title   studio  \
# 0        None         None       None                0.0     LG/S
# 1        None         None       None                0.0     FoxS
# 2        None  imdbDisplay       None                0.0     Sony
# 3        None         None       None                0.0       WB
# 4        None         None       None                0.0       WB
# ...       ...          ...        ...                ...      ...
# 1562     None         None       None                0.0     SGem
# 1563     None  imdbDisplay       None                0.0     Uni.
# 1564     None  imdbDisplay       None                0.0  WB (NL)
# 1565     None  imdbDisplay       None                0.0    Focus
# 1566     None  imdbDisplay       None                0.0     MBox
#
#       domestic_gross_movie_gross foreign_gross_movie_gross  year
# 0                     18800000.0                  42400000  2014
# 1                     21600000.0                    887000  2013
# 2                     75600000.0                  34600000  2011
# 3                     32700000.0                  72500000  2010
# 4                     32700000.0                  72500000  2010
# ...                          ...                       ...   ...
# 1562                  26800000.0                 285400000  2017
# 1563                  87000000.0                  18000000  2015
# 1564                  69200000.0                  48500000  2018
# 1565                   6800000.0                   5000000  2018
# 1566                    100000.0                    132000  2013
#
# [1567 rows x 19 columns]

# %%
final_gross_all = final_gross_df1.merge(final_gross_df2[["title", "domestic_gross_movie_gross", "foreign_gross_movie_gross"]],
                                        how="inner", on="title")
final_gross_all
# Out:
#        movie_id  averagerating  numvotes                     primary_title  \
# 0     tt1043726            4.2     50352            The Legend of Hercules
# 1     tt1171222            5.1      8296                     Baggage Claim
# 2     tt1210166            7.6    326657                         Moneyball
# 3     tt1212419            6.5     87288                         Hereafter
# 4     tt1212419            6.5     87288                         Hereafter
# ...         ...            ...       ...                               ...
# 1070  tt2125435            7.3     77440       Beasts of the Southern Wild
# 1071  tt2333784            6.1    156432                 The Expendables 3
# 1072  tt2592614            5.6     74979  Resident Evil: The Final Chapter
# 1073  tt2612800            5.7        37                           Sisters
# 1074  tt2704998            7.0    163279                        Game Night
#
#                         original_title  start_year  runtime_minutes  \
# 0               The Legend of Hercules        2014             99.0
# 1                        Baggage Claim        2013             96.0
# 2                            Moneyball        2011            133.0
# 3                            Hereafter        2010            129.0
# 4                            Hereafter        2010            129.0
# ...                                ...         ...              ...
# 1070       Beasts of the Southern Wild        2012             93.0
# 1071                 The Expendables 3        2014            126.0
# 1072  Resident Evil: The Final Chapter        2016            107.0
# 1073                        Schwestern        2013             84.0
# 1074                        Game Night        2018            100.0
#
#                          genres  ordering                        title  ...  \
# 0      Action,Adventure,Fantasy        20          thelegendofhercules  ...
# 1                        Comedy         5                 baggageclaim  ...
# 2         Biography,Drama,Sport        14                    moneyball  ...
# 3         Drama,Fantasy,Romance         4                    hereafter  ...
# 4         Drama,Fantasy,Romance         4                    hereafter  ...
# ...                         ...       ...                          ...  ...
# 1070    Adventure,Drama,Fantasy         6      beastsofthesouthernwild  ...
# 1071  Action,Adventure,Thriller        11              theexpendables3  ...
# 1072       Action,Horror,Sci-Fi         2  residentevilthefinalchapter  ...
# 1073                      Drama         2                      sisters  ...
# 1074        Action,Comedy,Crime        15                    gamenight  ...
#
#             types attributes is_original_title  id  release_date  \
# 0            None       None               0.0  42  Jan 10, 2014
# 1            None       None               0.0  38  Sep 27, 2013
# 2     imdbDisplay       None               0.0  15  Sep 23, 2011
# 3            None       None               0.0  61  Oct 15, 2010
# 4            None       None               0.0  61  Oct 15, 2010
# ...           ...        ...               ...  ..           ...
# 1070         None       None               0.0  18  Jun 27, 2012
# 1071         None       None               0.0  96  Aug 15, 2014
# 1072         None       None               0.0  84  Jan 27, 2017
# 1073  imdbDisplay       None               0.0  57  Dec 18, 2015
# 1074  imdbDisplay       None               0.0  94  Feb 23, 2018
#
#       production_budget domestic_gross_movie_budgets  \
# 0           $70,000,000                  $18,848,538
# 1            $8,500,000                  $21,569,509
# 2           $50,000,000                  $75,605,492
# 3           $50,000,000                  $32,746,941
# 4           $50,000,000                  $32,746,941
# ...                 ...                          ...
# 1070         $1,800,000                  $12,795,746
# 1071       $100,000,000                  $39,322,544
# 1072        $40,000,000                  $26,844,692
# 1073        $30,000,000                  $87,044,645
# 1074        $37,000,000                  $69,179,066
#
#      worldwide_gross_movie_budgets domestic_gross_movie_gross  \
# 0                      $58,953,319                 18800000.0
# 1                      $22,885,836                 21600000.0
# 2                     $111,300,835                 75600000.0
# 3                     $108,660,270                 32700000.0
# 4                     $108,660,270                 32700000.0
# ...                            ...                        ...
# 1070                   $23,265,132                 12800000.0
# 1071                  $209,461,378                 39300000.0
# 1072                  $314,101,190                 26800000.0
# 1073                  $106,030,660                 87000000.0
# 1074                  $117,378,084                 69200000.0
#
#      foreign_gross_movie_gross
# 0                     42400000
# 1                       887000
# 2                     34600000
# 3                     72500000
# 4                     72500000
# ...                        ...
# 1070                   8300000
# 1071                 175300000
# 1072                 285400000
# 1073                  18000000
# 1074                  48500000
#
# [1075 rows x 22 columns]
